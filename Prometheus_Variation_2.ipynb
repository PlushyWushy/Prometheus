# %% [markdown]
# <a href="https://colab.research.google.com/github/PlushyWushy/Prometheus/blob/main/Prometheus_Variation_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.4.26)

# %%
import time
import copy
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.distributions import Categorical
from torch.amp import autocast
from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import CosineAnnealingLR
import math
import inspect # For debugging
import logging
import gc # Garbage Collector interface
import itertools

# Silence verbose logs from the compiler
logging.getLogger("torch._dynamo").setLevel(logging.FATAL)
logging.getLogger("torch._inductor").setLevel(logging.FATAL)

try:
    import torch_geometric.nn as pyg_nn
    from torch_geometric.data import Data
    from torch_geometric.utils import to_undirected
    from torch_geometric.nn.dense.linear import Linear as PyGLinear
    PYG_AVAILABLE = True
except ImportError:
    PYG_AVAILABLE = False
    print("PyTorch Geometric not found. GNN MetaAgent will not be available if used.")

# =======================================================================
#  Constants & Configuration
# =======================================================================
PRE_EPOCHS=1; POST_EPOCHS=10; BATCHES_PER_EPOCH=None; BATCH_SIZE=512
LEARNING_RATE=1e-3; META_LEARNING_RATE=5e-4; MAX_GRAD_NORM=1.0
DEVICE=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if DEVICE.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8:
        print("Enabling TensorFloat32 matmul precision for supported GPU.")
        torch.set_float32_matmul_precision('high')

# --- Action Space with Skip Connections ---
EDIT_TYPE_ADD_CONV2D=0; EDIT_TYPE_ADD_RELU=1; EDIT_TYPE_RESIZE_CNN_CONV=2; EDIT_TYPE_ADD_SKIP=3
NUM_TARGET_CNN_EDIT_TYPES=4
DISCRETE_KERNEL_SIZES=[1,3]; DISCRETE_CH_MULT_ADD=[0.5,1.0,2.0];
DISCRETE_RESIZE_FACTORS = [0.25, 0.5, 0.75, 1.25, 1.5, 2.0, 3.0, 4.0]
NUM_STAGES_TARGET_CNN=3

# --- MetaAgent & RL Configuration ---
META_EDIT_NONE = 0; META_EDIT_DEEPEN_GNN = 1; META_EDIT_WIDEN_GNN_HIDDEN = 2
META_EDIT_DEEPEN_MLP_HEAD = 3
NUM_META_SELF_EDIT_TYPES = 4
META_SELF_EDIT_INTERVAL = 5
META_GNN_WIDEN_FACTOR = 2
MAX_GNN_LAYERS = None
MAX_GNN_HIDDEN_DIM = None
MAX_MLP_HEAD_SEQUENTIAL_DEPTH = None
INITIAL_GNN_HIDDEN_DIM = 32; INITIAL_NUM_GNN_LAYERS = 2
EDIT_TYPE_EMBED_DIM = 16

# --- Graph & State Representation ---
OP_TYPE_IDS = {'conv2d':1,'relu':2,'maxpool2d':3,'add': 8, 'input_placeholder':5,'none':0}
NODE_FEATURE_DIM = 7
NORMALIZATION_WIDTH_DIVISOR = 512.0; NORMALIZATION_IDX_DIVISOR = 50.0; NORMALIZATION_SPATIAL_DIVISOR = 32.0
GLOBAL_SUMMARY_FEATURE_DIM = 3 + 2
MAX_GLOBAL_HISTORY_LEN = 5

# =======================================================================
#  Custom Modules for Dynamic Graph
# =======================================================================
class AddWithProjection(nn.Module):
    def __init__(self, projection_module=None):
        super().__init__()
        self.projection = projection_module if projection_module is not None else nn.Identity()

    def forward(self, x_primary, x_skip):
        x_skip_projected = self.projection(x_skip)

        if x_primary.shape[2:] != x_skip_projected.shape[2:]:
            x_skip_projected = F.interpolate(x_skip_projected, size=x_primary.shape[2:], mode='bilinear', align_corners=False)

        return x_primary + x_skip_projected

# =======================================================================
#  Net2Net Utilities & Masking Helpers
# =======================================================================
def _valid_resize_indices(old_oc: int):
    valid = []
    for idx, f_resize in enumerate(DISCRETE_RESIZE_FACTORS):
        new_oc_resize = max(1, int(round(old_oc * f_resize)))
        if new_oc_resize != old_oc: valid.append(idx)
    if not valid and old_oc > 0 :
        try: valid.append(DISCRETE_RESIZE_FACTORS.index(1.0))
        except ValueError: pass
    if not valid: valid.append(0)
    return valid

def _mask_logits(logits: torch.Tensor, valid_indices: list):
    mask_val = torch.full_like(logits, float('-inf'))
    if valid_indices:
        valid_indices_tensor = torch.tensor(valid_indices, device=logits.device, dtype=torch.long)
        if valid_indices_tensor.numel() > 0:
            valid_indices_tensor = valid_indices_tensor[valid_indices_tensor < logits.shape[-1]]
            if valid_indices_tensor.numel() > 0:
                 mask_val[..., valid_indices_tensor] = 0.0
    return logits + mask_val

def _invalid_meta_indices(agent_meta_invalid):
    invalid_meta = []
    if MAX_GNN_LAYERS is not None and agent_meta_invalid.current_num_gnn_layers >= MAX_GNN_LAYERS:
        invalid_meta.append(META_EDIT_DEEPEN_GNN)
    if MAX_GNN_HIDDEN_DIM is not None and agent_meta_invalid.current_gnn_hidden_dim >= MAX_GNN_HIDDEN_DIM:
        invalid_meta.append(META_EDIT_WIDEN_GNN_HIDDEN)
    if MAX_MLP_HEAD_SEQUENTIAL_DEPTH is not None:
        eligible_heads_meta_invalid = agent_meta_invalid.get_mlp_head_names()
        all_mlp_heads_at_max_depth_meta_invalid = True
        if not eligible_heads_meta_invalid: all_mlp_heads_at_max_depth_meta_invalid = True
        else:
            for head_name_meta_invalid in eligible_heads_meta_invalid:
                current_depth_meta_invalid = agent_meta_invalid.head_depth_counters.get(head_name_meta_invalid, 1)
                if current_depth_meta_invalid < MAX_MLP_HEAD_SEQUENTIAL_DEPTH:
                    all_mlp_heads_at_max_depth_meta_invalid = False; break
        if all_mlp_heads_at_max_depth_meta_invalid:
            invalid_meta.append(META_EDIT_DEEPEN_MLP_HEAD)
    return invalid_meta

def net2wider_conv_output(conv: nn.Conv2d, factor: float, device='cpu') -> nn.Conv2d:
    old_oc = conv.out_channels; new_oc = max(1, int(round(old_oc * factor)))
    if new_oc == old_oc : return conv
    new_conv_module = nn.Conv2d(conv.in_channels, new_oc, conv.kernel_size, stride=conv.stride, padding=conv.padding, groups=conv.groups, bias=(conv.bias is not None)).to(device)
    with torch.no_grad():
        new_conv_module.weight.data.fill_(0); min_oc = min(old_oc, new_oc)
        if old_oc > 0:
            new_conv_module.weight.data[:min_oc] = conv.weight.data[:min_oc].clone()
            if new_oc > old_oc:
                for i in range(old_oc, new_oc): new_conv_module.weight.data[i] = conv.weight.data[i % old_oc].clone()
        if conv.bias is not None and new_conv_module.bias is not None:
            new_conv_module.bias.data.fill_(0)
            if old_oc > 0:
                new_conv_module.bias.data[:min_oc] = conv.bias.data[:min_oc].clone()
                if new_oc > old_oc:
                    for i in range(old_oc, new_oc): new_conv_module.bias.data[i] = conv.bias.data[i % old_oc].clone()
            elif new_oc > 0: nn.init.zeros_(new_conv_module.bias.data)
        elif new_conv_module.bias is not None: nn.init.zeros_(new_conv_module.bias.data)
    return new_conv_module

def net2thinner_conv_output(conv: nn.Conv2d, factor: float, device='cpu') -> nn.Conv2d:
    old_oc = conv.out_channels; new_oc = max(1, int(round(old_oc * factor)))
    if new_oc == old_oc: return conv
    new_conv_module = nn.Conv2d(conv.in_channels, new_oc, conv.kernel_size, stride=conv.stride, padding=conv.padding, groups=conv.groups, bias=(conv.bias is not None)).to(device)
    with torch.no_grad():
        if old_oc > 0 :
            new_conv_module.weight.data = conv.weight.data[:new_oc].clone()
            if conv.bias is not None and new_conv_module.bias is not None:
                 new_conv_module.bias.data = conv.bias.data[:new_oc].clone()
            elif new_conv_module.bias is not None: nn.init.zeros_(new_conv_module.bias.data)
    return new_conv_module

def resize_conv_output(conv: nn.Conv2d, factor: float, device='cpu') -> nn.Conv2d:
    if abs(factor - 1.0) < 1e-6 : return conv
    old_oc = conv.out_channels; new_oc = max(1, int(round(old_oc * factor)))
    if new_oc == old_oc and old_oc > 0: return conv
    if new_oc == old_oc and old_oc == 0 and factor != 1.0 : pass
    elif new_oc == old_oc: return conv
    if new_oc > old_oc: return net2wider_conv_output(conv, float(new_oc)/old_oc if old_oc > 0 else factor, device)
    else: return net2thinner_conv_output(conv, float(new_oc)/old_oc if old_oc > 0 else factor, device)

def adapt_conv_input_channels(conv: nn.Conv2d, new_in_channels: int, device='cpu') -> nn.Conv2d:
    if conv.in_channels == new_in_channels: return conv
    new_in_channels = max(1, new_in_channels); old_ic = conv.in_channels; new_groups = conv.groups
    if (conv.groups == old_ic and old_ic != new_in_channels and old_ic !=0) or \
       (conv.groups != 1 and new_in_channels % conv.groups != 0):
        new_groups = new_in_channels if (conv.groups == old_ic and old_ic !=0) else 1
    new_conv_module = nn.Conv2d(new_in_channels, conv.out_channels, conv.kernel_size, stride=conv.stride, padding=conv.padding, groups=new_groups, bias=(conv.bias is not None)).to(device)
    with torch.no_grad():
        if old_ic == 0 or (new_groups != conv.groups and (conv.groups !=1 or new_groups ==1)): nn.init.kaiming_normal_(new_conv_module.weight, mode='fan_in', nonlinearity='relu')
        elif new_groups == 1 and conv.groups == 1 :
            w_new_conv_adapt = torch.zeros_like(new_conv_module.weight.data)
            for o in range(conv.out_channels):
                for i_new in range(new_in_channels):
                    if i_new < old_ic: w_new_conv_adapt[o, i_new].copy_(conv.weight.data[o, i_new])
                    else:
                        if old_ic > 0: w_new_conv_adapt[o, i_new].copy_(conv.weight.data[o, i_new % old_ic]); w_new_conv_adapt[o, i_new] /= max(1.0, (new_in_channels / old_ic))
                        else: nn.init.kaiming_normal_(w_new_conv_adapt[o, i_new].unsqueeze(0).unsqueeze(0), mode='fan_in', nonlinearity='relu')
            new_conv_module.weight.data.copy_(w_new_conv_adapt)
        else: nn.init.kaiming_normal_(new_conv_module.weight, mode='fan_in', nonlinearity='relu')
        if conv.bias is not None and new_conv_module.bias is not None: new_conv_module.bias.data.copy_(conv.bias.data)
        elif new_conv_module.bias is not None: nn.init.zeros_(new_conv_module.bias.data)
    return new_conv_module

def net2deeper_linear_insert_identity(head_module_owner: nn.Module, head_name: str, device='cpu'):
    if not hasattr(head_module_owner, head_name): print(f"Err: Attr {head_name} not found for deepening"); return False
    original_component = getattr(head_module_owner, head_name)
    if isinstance(original_component, nn.Linear):
        identity_dim = original_component.out_features
        if identity_dim <= 0: print(f"Cannot insert identity for dim {identity_dim} in Linear head {head_name}"); return False
        identity_layer = nn.Linear(identity_dim, identity_dim, bias=True).to(device)
        with torch.no_grad(): identity_layer.weight.data.copy_(torch.eye(identity_dim,device=device)); identity_layer.bias.data.fill_(0)
        setattr(head_module_owner,head_name,nn.Sequential(original_component,identity_layer).to(device)); print(f"  Deepened MLP head '{head_name}' (Linear -> Sequential)")
        return True
    elif isinstance(original_component, nn.Sequential):
        if not original_component or not isinstance(original_component[-1],nn.Linear): print(f"Cannot deepen Seq head '{head_name}', last not Linear."); return False
        identity_dim = original_component[-1].in_features
        if identity_dim <= 0: print(f"Cannot insert identity for dim {identity_dim} in Seq head {head_name}"); return False
        identity_layer = nn.Linear(identity_dim, identity_dim, bias=True).to(device)
        with torch.no_grad(): identity_layer.weight.data.copy_(torch.eye(identity_dim,device=device)); identity_layer.bias.data.fill_(0)
        new_seq_layers = nn.ModuleList([l for l in original_component[:-1]] + [identity_layer, original_component[-1]])
        setattr(head_module_owner,head_name,nn.Sequential(*new_seq_layers).to(device)); print(f"  Deepened Seq head '{head_name}'.")
        return True
    print(f"Err: Head '{head_name}' type {type(original_component)} not Linear/Seq for deepening.");
    return False

def _get_gcn_conv_linear_submodule(gcn_layer):
    if hasattr(gcn_layer, 'lin') and (isinstance(gcn_layer.lin, nn.Linear) or (PYG_AVAILABLE and isinstance(gcn_layer.lin, PyGLinear))):
        return gcn_layer.lin
    return None

if PYG_AVAILABLE:
    def widen_gcn_conv_hidden(gcn_layer: pyg_nn.GCNConv, new_hidden_dim: int, prev_layer_out_dim: int, device='cpu'):
        old_hidden_dim = gcn_layer.out_channels
        if new_hidden_dim == old_hidden_dim: return gcn_layer, False
        new_gcn = pyg_nn.GCNConv(prev_layer_out_dim,new_hidden_dim,bias=(gcn_layer.bias is not None), improved=gcn_layer.improved,add_self_loops=gcn_layer.add_self_loops, normalize=gcn_layer.normalize).to(device)
        with torch.no_grad():
            gcn_lin_original = _get_gcn_conv_linear_submodule(gcn_layer)
            gcn_lin_new = _get_gcn_conv_linear_submodule(new_gcn)
            if gcn_lin_original is None or gcn_lin_new is None: return new_gcn, True
            orig_lin_w = gcn_lin_original.weight.data; new_lin_w_target = gcn_lin_new.weight.data
            min_out = min(old_hidden_dim,new_hidden_dim); new_lin_w_fill = torch.zeros_like(new_lin_w_target)
            new_lin_w_fill[:min_out,:] = orig_lin_w[:min_out,:].clone()
            if new_hidden_dim>old_hidden_dim and old_hidden_dim>0:
                for r_idx in range(old_hidden_dim,new_hidden_dim): new_lin_w_fill[r_idx,:]=orig_lin_w[r_idx%old_hidden_dim,:].clone()
            new_lin_w_target.copy_(new_lin_w_fill)
            if gcn_layer.bias is not None and new_gcn.bias is not None:
                orig_gcn_b = gcn_layer.bias.data; new_gcn_b_target = new_gcn.bias.data
                new_gcn_b_fill = torch.zeros_like(new_gcn_b_target)
                new_gcn_b_fill[:min_out] = orig_gcn_b[:min_out].clone()
                if new_hidden_dim>old_hidden_dim and old_hidden_dim>0:
                    for r_idx_bias in range(old_hidden_dim,new_hidden_dim): new_gcn_b_fill[r_idx_bias]=orig_gcn_b[r_idx_bias%old_hidden_dim].clone()
                new_gcn_b_target.copy_(new_gcn_b_fill)
            elif new_gcn.bias is not None : nn.init.zeros_(new_gcn.bias.data)
        return new_gcn,True

    def adapt_gcn_conv_input_dim(gcn_layer: pyg_nn.GCNConv, new_input_dim: int, device='cpu'):
        old_input_dim = gcn_layer.in_channels
        if new_input_dim == old_input_dim: return gcn_layer, False
        new_gcn = pyg_nn.GCNConv(new_input_dim,gcn_layer.out_channels,bias=(gcn_layer.bias is not None), improved=gcn_layer.improved,add_self_loops=gcn_layer.add_self_loops,normalize=gcn_layer.normalize).to(device)
        with torch.no_grad():
            gcn_lin_original_adapt = _get_gcn_conv_linear_submodule(gcn_layer)
            gcn_lin_new_adapt = _get_gcn_conv_linear_submodule(new_gcn)
            if gcn_lin_original_adapt is None or gcn_lin_new_adapt is None: return new_gcn,True
            orig_lin_w_adapt = gcn_lin_original_adapt.weight.data; new_lin_w_target_adapt = gcn_lin_new_adapt.weight.data
            min_in_adapt = min(old_input_dim,new_input_dim); new_lin_w_fill_adapt = torch.zeros_like(new_lin_w_target_adapt)
            if old_input_dim>0:
                new_lin_w_fill_adapt[:,:min_in_adapt] = orig_lin_w_adapt[:,:min_in_adapt].clone()
                if new_input_dim > old_input_dim:
                    for c_adapt in range(old_input_dim,new_input_dim):
                        new_lin_w_fill_adapt[:,c_adapt]=orig_lin_w_adapt[:,c_adapt%old_input_dim].clone()
                        new_lin_w_fill_adapt[:,c_adapt]/=max(1.0,(new_input_dim/old_input_dim))
                new_lin_w_target_adapt.copy_(new_lin_w_fill_adapt)
            if gcn_layer.bias is not None and new_gcn.bias is not None: new_gcn.bias.data.copy_(gcn_layer.bias.data)
            elif new_gcn.bias is not None: nn.init.zeros_(new_gcn.bias.data)
        return new_gcn, True

    def create_identity_gcn_layer(dim: int, device='cpu', **gcn_kwargs):
        identity_gcn = pyg_nn.GCNConv(dim,dim,bias=gcn_kwargs.get('bias',True), normalize=gcn_kwargs.get('normalize',True), add_self_loops=gcn_kwargs.get('add_self_loops',True), improved=gcn_kwargs.get('improved',False)).to(device)
        with torch.no_grad():
            gcn_lin_identity = _get_gcn_conv_linear_submodule(identity_gcn)
            if gcn_lin_identity is not None:
                if gcn_lin_identity.weight.shape[0] == gcn_lin_identity.weight.shape[1]: gcn_lin_identity.weight.data.copy_(torch.eye(dim,device=device))
                else: nn.init.kaiming_uniform_(gcn_lin_identity.weight, a=math.sqrt(5))
                if hasattr(gcn_lin_identity, 'bias') and gcn_lin_identity.bias is not None: gcn_lin_identity.bias.data.fill_(0.0)
            if identity_gcn.bias is not None: identity_gcn.bias.data.fill_(0.0)
        return identity_gcn

# =======================================================================
#  Dynamic Models (TargetCNN)
# =======================================================================
class DynamicStageModule(nn.Module):
    def __init__(self, stage_idx_dyn, initial_in_channels_dyn, initial_spatial_size_dyn, max_ops_dyn=None):
        super().__init__()
        self.stage_idx = stage_idx_dyn
        self.initial_in_channels = initial_in_channels_dyn
        self.initial_spatial_size = initial_spatial_size_dyn
        self.max_ops = max_ops_dyn
        self.ops = nn.ModuleList()
        self.op_descriptions = []

    def add_op(self, op_module_dyn, op_description_dyn, insert_at=None):
        if self.max_ops is not None and len(self.ops) >= self.max_ops:
            return False
        if insert_at is None:
            self.ops.append(op_module_dyn)
            self.op_descriptions.append(op_description_dyn)
        else:
            self.ops.insert(insert_at, op_module_dyn)
            self.op_descriptions.insert(insert_at, op_description_dyn)
        return True

    def get_op_output_properties(self, op_idx):
        if op_idx == -1:
            return self.initial_in_channels, self.initial_spatial_size
        if 0 <= op_idx < len(self.op_descriptions):
            desc = self.op_descriptions[op_idx]
            return desc.get('out_channels', 0), desc.get('out_spatial', 0)
        raise IndexError(f"Operator index {op_idx} out of range for stage {self.stage_idx} with {len(self.ops)} ops.")

    def get_current_out_properties(self):
        if not self.op_descriptions:
            return self.initial_in_channels, self.initial_spatial_size
        return self.get_op_output_properties(len(self.ops) - 1)

    def forward(self, x_dyn):
        outputs_history_dyn = {-1: x_dyn}
        for i_dyn, op_desc_item_dyn in enumerate(self.op_descriptions):
            op_module_fwd_dyn = self.ops[i_dyn]
            input_indices_dyn = op_desc_item_dyn.get('input_indices', [-1])
            if not isinstance(input_indices_dyn, list): input_indices_dyn = [input_indices_dyn]

            current_op_inputs_dyn = []
            for source_op_local_idx_dyn in input_indices_dyn:
                if not (-1 <= source_op_local_idx_dyn < i_dyn):
                     source_op_local_idx_dyn = (i_dyn - 1) if i_dyn > 0 else -1

                if source_op_local_idx_dyn in outputs_history_dyn:
                    current_op_inputs_dyn.append(outputs_history_dyn[source_op_local_idx_dyn])
                else:
                    default_input_key_dyn = (i_dyn-1) if i_dyn > 0 else -1
                    current_op_inputs_dyn.append(outputs_history_dyn.get(default_input_key_dyn, x_dyn))
            try:
                if not current_op_inputs_dyn:
                    op_output_dyn = op_module_fwd_dyn(x_dyn)
                elif len(current_op_inputs_dyn) == 1:
                    op_output_dyn = op_module_fwd_dyn(current_op_inputs_dyn[0])
                else:
                    op_output_dyn = op_module_fwd_dyn(*current_op_inputs_dyn)
            except Exception as e_dyn_fwd:
                print(f"CRITICAL Error in DynamicStageModule op {i_dyn}, type {op_desc_item_dyn.get('type','Unknown')}, stage {self.stage_idx}: {e_dyn_fwd}"); raise e_dyn_fwd
            outputs_history_dyn[i_dyn] = op_output_dyn
        return outputs_history_dyn[len(self.ops)-1] if self.ops else x_dyn


class TargetCNN(nn.Module):
    def __init__(self, num_classes_cnn=10, num_stages_cnn=NUM_STAGES_TARGET_CNN, init_model_ch_cnn=16, input_spatial_size=32):
        super().__init__()
        self.num_stages = num_stages_cnn
        self.stages = nn.ModuleList()
        current_channels_cnn = 3
        current_spatial_size = input_spatial_size
        self.input_placeholder_desc = {'type': 'input_placeholder', 'out_channels': current_channels_cnn, 'out_spatial': input_spatial_size, 'input_indices': []}

        stage_base_channels_cnn = [init_model_ch_cnn, init_model_ch_cnn * 2, init_model_ch_cnn * 4]
        for i_cnn_stage in range(num_stages_cnn):
            stage_module_cnn = DynamicStageModule(i_cnn_stage, current_channels_cnn, current_spatial_size, max_ops_dyn=None)
            target_stage_out_channels_cnn = stage_base_channels_cnn[i_cnn_stage] if i_cnn_stage < len(stage_base_channels_cnn) else stage_base_channels_cnn[-1]

            conv1 = nn.Conv2d(current_channels_cnn, target_stage_out_channels_cnn, 3, 1, 1, bias=False).to(DEVICE)
            stage_module_cnn.add_op(conv1, {'type': 'conv2d', 'out_channels': target_stage_out_channels_cnn, 'out_spatial': current_spatial_size, 'input_indices': [-1]})
            relu1 = nn.ReLU(inplace=False).to(DEVICE)
            stage_module_cnn.add_op(relu1, {'type': 'relu', 'out_channels': target_stage_out_channels_cnn, 'out_spatial': current_spatial_size, 'input_indices': [0]})

            current_channels_after_block_cnn, current_spatial_after_block = stage_module_cnn.get_current_out_properties()
            if i_cnn_stage < num_stages_cnn - 1 :
                pool_cnn = nn.MaxPool2d(2, 2).to(DEVICE)
                current_spatial_size //= 2
                stage_module_cnn.add_op(pool_cnn, {'type': 'maxpool2d', 'out_channels': current_channels_after_block_cnn, 'out_spatial': current_spatial_size, 'input_indices': [1]})

            self.stages.append(stage_module_cnn)
            current_channels_cnn, current_spatial_size = stage_module_cnn.get_current_out_properties()

        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        fc_in_features_cnn, _ = self.get_last_stage_out_properties()
        self.fc = nn.Linear(max(1, fc_in_features_cnn), num_classes_cnn).to(DEVICE)

    def forward(self,x_cnn_fwd):
        for stage_cnn_fwd in self.stages: x_cnn_fwd=stage_cnn_fwd(x_cnn_fwd)
        return self.fc(torch.flatten(self.adaptive_pool(x_cnn_fwd),1))

    def get_last_stage_out_properties(self):
        if not self.stages:
            return self.input_placeholder_desc['out_channels'], self.input_placeholder_desc['out_spatial']
        return self.stages[-1].get_current_out_properties()


# =======================================================================
#  GNN MetaAgent
# =======================================================================
if PYG_AVAILABLE:
    class MetaAgentGNN(nn.Module):
        def __init__(self, node_feature_dim_agent=NODE_FEATURE_DIM, initial_gnn_hidden_dim_agent=INITIAL_GNN_HIDDEN_DIM, initial_num_gnn_layers_agent=INITIAL_NUM_GNN_LAYERS,
                     global_history_dim_flat_agent=GLOBAL_SUMMARY_FEATURE_DIM * MAX_GLOBAL_HISTORY_LEN, device_to_use_agent=DEVICE, **kwargs_agent):
            super().__init__()
            self.device = device_to_use_agent; self.node_feature_dim = node_feature_dim_agent; self.current_gnn_hidden_dim = initial_gnn_hidden_dim_agent
            self.current_num_gnn_layers = initial_num_gnn_layers_agent; self.action_space_sizes = {k: v for k, v in kwargs_agent.items()}; self.head_depth_counters = {}

            self.edit_type_embedding = nn.Embedding(self.action_space_sizes['num_edit_types'], EDIT_TYPE_EMBED_DIM).to(self.device)

            self.policy_head_names = ['head_target_loc_stage', 'head_target_conv_kernel', 'head_target_conv_ch_mult', 'head_target_resize_factor']
            self._build_gnn_layers(); self._build_mlp_heads(global_history_dim_flat_agent)

        def _build_gnn_layers(self):
            self.gnn_layers = nn.ModuleList(); current_in_dim = self.node_feature_dim
            if self.current_num_gnn_layers > 0:
                for _ in range(self.current_num_gnn_layers):
                    out_dim = self.current_gnn_hidden_dim
                    self.gnn_layers.append(pyg_nn.GCNConv(current_in_dim, out_dim, bias=True, normalize=True, add_self_loops=True).to(self.device)); current_in_dim = out_dim

        def _get_current_gnn_output_dim(self):
            if self.current_num_gnn_layers == 0: return self.node_feature_dim
            return self.current_gnn_hidden_dim

        def _build_mlp_heads(self, global_history_dim_flat):
            gnn_output_dim = self._get_current_gnn_output_dim();
            base_input_dim = gnn_output_dim + global_history_dim_flat
            self.heads_input_dim_global_current = base_input_dim

            self.head_target_edit_type = nn.Linear(base_input_dim, self.action_space_sizes['num_edit_types'])
            self.head_meta_self_edit_type = nn.Linear(base_input_dim, NUM_META_SELF_EDIT_TYPES)
            self.head_value = nn.Linear(base_input_dim, 1)

            conditional_input_dim = base_input_dim + EDIT_TYPE_EMBED_DIM
            self.head_target_loc_stage = nn.Linear(conditional_input_dim, self.action_space_sizes['num_stages_target'])
            self.head_target_conv_kernel = nn.Linear(conditional_input_dim, len(DISCRETE_KERNEL_SIZES))
            self.head_target_conv_ch_mult = nn.Linear(conditional_input_dim, len(DISCRETE_CH_MULT_ADD))
            self.head_target_resize_factor = nn.Linear(conditional_input_dim, len(DISCRETE_RESIZE_FACTORS))

            self.head_resize_op_selector_scorer = nn.Linear(gnn_output_dim, 1)
            self.head_skip_source_scorer = nn.Linear(gnn_output_dim, 1)
            self.head_skip_destination_scorer = nn.Linear(gnn_output_dim, 1)

            all_head_names = self.policy_head_names + ['head_target_edit_type', 'head_meta_self_edit_type', 'head_value', 'head_resize_op_selector_scorer', 'head_skip_source_scorer', 'head_skip_destination_scorer']
            for name, module in self.named_children():
                if name in all_head_names or name == 'edit_type_embedding':
                    module.to(self.device)
            self.head_depth_counters = {name: (len(getattr(self,name)) if isinstance(getattr(self,name),nn.Sequential) else 1) for name in self.get_mlp_head_names()}

        def get_mlp_head_names(self):
             return self.policy_head_names

        def _process_graph_and_state(self, graph_data, global_states_history_flat):
            node_features, edge_index = graph_data.x, graph_data.edge_index
            embeddings = node_features
            if self.current_num_gnn_layers > 0 and graph_data.num_nodes > 0:
                for gnn_layer in self.gnn_layers:
                    embeddings = F.relu(gnn_layer(embeddings, edge_index))
            elif graph_data.num_nodes == 0:
                embeddings = torch.empty(0, self._get_current_gnn_output_dim(), device=self.device)

            batch_vector = graph_data.batch
            if batch_vector is None and embeddings.numel() > 0:
                batch_vector = torch.zeros(embeddings.size(0), dtype=torch.long, device=self.device)

            graph_embedding = pyg_nn.global_mean_pool(embeddings, batch_vector) if graph_data.num_nodes > 0 else torch.zeros(1, self._get_current_gnn_output_dim(), device=self.device)

            if global_states_history_flat.ndim == 1: global_states_history_flat = global_states_history_flat.unsqueeze(0)
            if graph_embedding.ndim == 1: graph_embedding = graph_embedding.unsqueeze(0)

            combined_features = torch.cat((graph_embedding, global_states_history_flat), dim=1)
            return combined_features, embeddings

        def forward(self, graph_data, global_states_history_flat):
            combined_features, node_embeddings = self._process_graph_and_state(graph_data, global_states_history_flat)

            l_te = self.head_target_edit_type(combined_features)
            l_mse = self.head_meta_self_edit_type(combined_features)
            value_pred = self.head_value(combined_features)

            return l_te, l_mse, value_pred, node_embeddings, combined_features

        def get_conditional_logits(self, base_state_embedding, chosen_edit_type_tensor):
            type_emb = self.edit_type_embedding(chosen_edit_type_tensor)
            conditional_state = torch.cat([base_state_embedding, type_emb], dim=1)
            logits = {}
            edit_type = chosen_edit_type_tensor.item()

            logits['stage'] = self.head_target_loc_stage(conditional_state)

            if edit_type == EDIT_TYPE_ADD_CONV2D:
                logits['kernel'] = self.head_target_conv_kernel(conditional_state)
                logits['ch_mult'] = self.head_target_conv_ch_mult(conditional_state)
            elif edit_type == EDIT_TYPE_RESIZE_CNN_CONV:
                logits['resize_factor'] = self.head_target_resize_factor(conditional_state)

            return logits

        def deepen_gnn(self, device='cpu'):
            if MAX_GNN_LAYERS is not None and self.current_num_gnn_layers >= MAX_GNN_LAYERS: return False
            print(f"  Deepening MetaAgentGNN: GNN Layers {self.current_num_gnn_layers} -> {self.current_num_gnn_layers + 1}")
            new_layer_in_dim = self._get_current_gnn_output_dim()
            if self.current_num_gnn_layers == 0 : new_gcn_layer = pyg_nn.GCNConv(self.node_feature_dim, self.current_gnn_hidden_dim, bias=True, normalize=True, add_self_loops=True).to(device)
            else: new_gcn_layer = create_identity_gcn_layer(self.current_gnn_hidden_dim, device=device) if new_layer_in_dim == self.current_gnn_hidden_dim else pyg_nn.GCNConv(new_layer_in_dim, self.current_gnn_hidden_dim, bias=True, normalize=True, add_self_loops=True).to(device)
            self.gnn_layers.append(new_gcn_layer); self.current_num_gnn_layers += 1
            if self._get_current_gnn_output_dim() + (GLOBAL_SUMMARY_FEATURE_DIM * MAX_GLOBAL_HISTORY_LEN) != self.heads_input_dim_global_current:
                 self._build_mlp_heads(GLOBAL_SUMMARY_FEATURE_DIM * MAX_GLOBAL_HISTORY_LEN)
            return True

        def widen_gnn_hidden_dim(self, factor=META_GNN_WIDEN_FACTOR, device='cpu'):
            old_dim = self.current_gnn_hidden_dim; new_dim = max(INITIAL_GNN_HIDDEN_DIM // 2 if INITIAL_GNN_HIDDEN_DIM > 1 else 1 , int(round(old_dim * factor)))
            if MAX_GNN_HIDDEN_DIM is not None: new_dim = min(new_dim, MAX_GNN_HIDDEN_DIM)
            if new_dim == old_dim or self.current_num_gnn_layers == 0: return False
            print(f"  Widening MetaAgentGNN: GNN Hidden Dim {old_dim} -> {new_dim}")
            new_gnn_list = nn.ModuleList(); current_in_dim = self.node_feature_dim; any_changed = False
            for i in range(self.current_num_gnn_layers):
                original_gcn = self.gnn_layers[i]; temp_gcn = original_gcn
                if original_gcn.in_channels != current_in_dim: temp_gcn, chg1 = adapt_gcn_conv_input_dim(original_gcn, current_in_dim, device); any_changed |= chg1
                final_gcn, chg2 = widen_gcn_conv_hidden(temp_gcn, new_dim, current_in_dim, device); any_changed |= chg2
                new_gnn_list.append(final_gcn); current_in_dim = new_dim
            if not any_changed and new_dim != old_dim : return False
            self.gnn_layers = new_gnn_list; self.current_gnn_hidden_dim = new_dim; self._build_mlp_heads(GLOBAL_SUMMARY_FEATURE_DIM * MAX_GLOBAL_HISTORY_LEN)
            return True

        def deepen_one_mlp_head(self, head_attr_name, device='cpu'):
            original_comp = getattr(self, head_attr_name, None)
            if original_comp is None: return False
            current_depth = self.head_depth_counters.get(head_attr_name, len(original_comp) if isinstance(original_comp, nn.Sequential) else 1)
            if MAX_MLP_HEAD_SEQUENTIAL_DEPTH is not None and current_depth >= MAX_MLP_HEAD_SEQUENTIAL_DEPTH : return False
            changed = net2deeper_linear_insert_identity(self, head_attr_name, device=device)
            if changed: self.head_depth_counters[head_attr_name] = len(getattr(self, head_attr_name)) if isinstance(getattr(self, head_attr_name), nn.Sequential) else 1
            return changed

# =======================================================================
#  DEITI System
# =======================================================================
class DEITI:
    def __init__(self):
        if not PYG_AVAILABLE: raise ImportError("PyTorch Geometric required for DEITI.")
        self.device=DEVICE
        self.target_cnn = TargetCNN().to(DEVICE)
        self.meta_agent = MetaAgentGNN(
            device_to_use_agent=self.device, num_edit_types=NUM_TARGET_CNN_EDIT_TYPES, num_stages_target=NUM_STAGES_TARGET_CNN,
            num_kernel_sizes=len(DISCRETE_KERNEL_SIZES), num_ch_mults=len(DISCRETE_CH_MULT_ADD), num_resize_factors=len(DISCRETE_RESIZE_FACTORS)
        ).to(DEVICE)

        self.criterion_target=nn.CrossEntropyLoss(label_smoothing=0.1)
        self.global_states_history_buffer=[]
        self.amp_scaler = torch.amp.GradScaler(enabled=(self.device.type=='cuda'))
        self._init_dataloaders(); self._ensure_target_cnn_consistency()
        self.opt_target = optim.AdamW(self.target_cnn.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
        self.sched_target = CosineAnnealingLR(self.opt_target, T_max=PRE_EPOCHS+POST_EPOCHS)
        self.opt_meta = optim.Adam(self.meta_agent.parameters(), lr=META_LEARNING_RATE)

    def mixup_data(self, x, y, alpha=1.0):
        if alpha > 0: lam = np.random.beta(alpha, alpha)
        else: lam = 1
        batch_size = x.size()[0]
        index = torch.randperm(batch_size, device=self.device)
        mixed_x = lam * x + (1 - lam) * x[index, :]
        y_a, y_b = y, y[index]
        return mixed_x, y_a, y_b, lam

    def mixup_criterion(self, pred, y_a, y_b, lam):
        return lam * self.criterion_target(pred, y_a) + (1 - lam) * self.criterion_target(pred, y_b)

    def _init_dataloaders(self):
        cifar10_mean, cifar10_std = (0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)
        train_transforms = transforms.Compose([
            transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
            transforms.RandomHorizontalFlip(),
            transforms.AutoAugment(transforms.AutoAugmentPolicy.CIFAR10),
            transforms.ToTensor(),
            transforms.Normalize(cifar10_mean, cifar10_std),
            transforms.RandomErasing(p=0.25, scale=(0.02, 0.33)),
        ])
        val_transforms=transforms.Compose([transforms.ToTensor(), transforms.Normalize(cifar10_mean, cifar10_std)])
        try:
            tr_ds = torchvision.datasets.CIFAR10('./data', train=True, download=True, transform=train_transforms)
            val_ds = torchvision.datasets.CIFAR10('./data', train=False, download=True, transform=val_transforms)
        except Exception as e:
            print(f"CIFAR-10 download failed: {e}. Using FakeData.")
            tr_ds, val_ds = torchvision.datasets.FakeData((BATCH_SIZE*50),(3,32,32),10,train_transforms), torchvision.datasets.FakeData((BATCH_SIZE*20),(3,32,32),10,val_transforms)
        num_workers = 4 if self.device.type == 'cuda' else 0
        print(f"Using {num_workers} workers for data loading.")
        self.train_loader = DataLoader(tr_ds, BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=self.device.type=='cuda')
        self.val_loader = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=self.device.type=='cuda')

    def _create_target_cnn_graph_data(self):
        nodes, src, tgt, op_map, gid = {}, [], [], {}, 0
        _, initial_spatial = self.target_cnn.input_placeholder_desc['out_channels'], self.target_cnn.input_placeholder_desc['out_spatial']

        current_spatial_map = {-1: initial_spatial}
        for si, sm in enumerate(self.target_cnn.stages):
            stage_initial_spatial = current_spatial_map.get(si-1, initial_spatial)
            op_output_props = {-1: (sm.initial_in_channels, stage_initial_spatial)}

            for oi, od in enumerate(sm.op_descriptions):
                op_map[(si, oi)] = gid
                op_type_str = od.get('type', 'none')

                input_indices = od.get('input_indices', [-1])
                input_indices = input_indices if isinstance(input_indices, list) else [input_indices]
                prev_op_idx = input_indices[0]
                _, expected_in_spatial = op_output_props.get(prev_op_idx, (sm.initial_in_channels, stage_initial_spatial))

                is_conv = 1.0 if op_type_str == 'conv2d' else 0.0
                out_spatial = expected_in_spatial
                stride_val = 1
                if op_type_str == 'maxpool2d':
                    stride_val = sm.ops[oi].stride
                    out_spatial //= 2 # Assuming stride 2 for maxpool
                elif op_type_str == 'conv2d':
                    stride_val = sm.ops[oi].stride[0]
                    out_spatial //= stride_val

                op_output_props[oi] = (od.get('out_channels'), out_spatial)
                od['out_spatial'] = out_spatial

                nf = [
                    float(OP_TYPE_IDS.get(op_type_str, 0)),
                    float(od.get('out_channels', 0)) / NORMALIZATION_WIDTH_DIVISOR,
                    float(si) / max(1, NUM_STAGES_TARGET_CNN - 1),
                    float(oi) / max(1, len(sm.ops) - 1),
                    is_conv,
                    float(stride_val -1),
                    float(out_spatial) / NORMALIZATION_SPATIAL_DIVISOR,
                ]
                nodes[gid] = nf
                gid += 1
            if sm.op_descriptions:
                 current_spatial_map[si] = op_output_props[len(sm.ops)-1][1]
            else:
                 current_spatial_map[si] = stage_initial_spatial


        s_out_gid_map = {s: op_map.get((s, len(sm_loop.ops) - 1), -1) for s, sm_loop in enumerate(self.target_cnn.stages) if sm_loop.ops}

        for si, sm in enumerate(self.target_cnn.stages):
            for oi, od in enumerate(sm.op_descriptions):
                cur_gid = op_map.get((si, oi), -1)
                if cur_gid == -1: continue

                in_ids = od.get('input_indices', [-1] if oi == 0 else [oi - 1])
                in_ids = in_ids if isinstance(in_ids, list) else [in_ids]

                for lsid in in_ids:
                    if lsid == -1:
                        sgid = s_out_gid_map.get(si - 1, -1) if si > 0 else -1
                    else:
                        sgid = op_map.get((si, lsid), -1)

                    if sgid != -1:
                        src.append(sgid)
                        tgt.append(cur_gid)

        x = torch.tensor([nodes[i] for i in range(gid)] if gid > 0 else [[0.] * NODE_FEATURE_DIM], dtype=torch.float32, device=self.device)
        eidx = torch.tensor([src, tgt], dtype=torch.long, device=self.device) if src else torch.empty((2, 0), dtype=torch.long, device=self.device)
        return Data(x=x, edge_index=eidx, batch=torch.zeros(x.size(0), dtype=torch.long, device=self.device) if x.size(0) > 0 else None), op_map

    def _ensure_target_cnn_consistency(self):
        current_channels, current_spatial = self.target_cnn.input_placeholder_desc['out_channels'], self.target_cnn.input_placeholder_desc['out_spatial']

        for stage_module in self.target_cnn.stages:
            stage_module.initial_in_channels = current_channels
            stage_module.initial_spatial_size = current_spatial

            op_output_props = {-1: (current_channels, current_spatial)}

            for i, op in enumerate(stage_module.ops):
                desc = stage_module.op_descriptions[i]
                input_indices = desc.get('input_indices', [-1])
                input_indices = input_indices if isinstance(input_indices, list) else [input_indices]

                prev_op_idx = input_indices[0] if input_indices else -1
                expected_in_channels, expected_in_spatial = op_output_props.get(prev_op_idx, (current_channels, current_spatial))

                if isinstance(op, nn.Conv2d):
                    if op.in_channels != expected_in_channels:
                        new_op = adapt_conv_input_channels(op, expected_in_channels, self.device)
                        stage_module.ops[i] = new_op
                        op = new_op
                    desc['out_channels'] = op.out_channels
                    desc['out_spatial'] = expected_in_spatial // op.stride[0]

                elif isinstance(op, nn.ReLU):
                    desc['out_channels'] = expected_in_channels
                    desc['out_spatial'] = expected_in_spatial

                elif isinstance(op, nn.MaxPool2d):
                    desc['out_channels'] = expected_in_channels
                    desc['out_spatial'] = expected_in_spatial // op.stride

                elif isinstance(op, AddWithProjection):
                    primary_ch, primary_sp = op_output_props[input_indices[0]]
                    skip_ch, _ = op_output_props[input_indices[1]]

                    if primary_ch != skip_ch:
                        op.projection = nn.Sequential(
                            nn.Conv2d(skip_ch, primary_ch, kernel_size=1, bias=False),
                            nn.BatchNorm2d(primary_ch)
                        ).to(self.device)
                    else:
                        op.projection = nn.Identity()

                    desc['out_channels'], desc['out_spatial'] = primary_ch, primary_sp

                op_output_props[i] = (desc.get('out_channels'), desc.get('out_spatial'))

            current_channels, current_spatial = stage_module.get_current_out_properties()

        final_channels, _ = self.target_cnn.get_last_stage_out_properties()
        fc_in_features = max(1, final_channels)
        if self.target_cnn.fc.in_features != fc_in_features:
            old_fc = self.target_cnn.fc
            self.target_cnn.fc = nn.Linear(fc_in_features, old_fc.out_features).to(self.device)

    def _apply_target_cnn_edit(self, actions):
        edit_type, stage_idx = actions['target_edit_type'].item(), actions['target_loc_stage'].item()
        if not (0 <= stage_idx < len(self.target_cnn.stages)): return False
        stage = self.target_cnn.stages[stage_idx]; changed = False

        if edit_type == EDIT_TYPE_RESIZE_CNN_CONV:
            op_idx = actions.get('target_actual_op_idx_in_stage', -1)
            if op_idx != -1 and 0 <= op_idx < len(stage.ops) and isinstance(stage.ops[op_idx], nn.Conv2d):
                op_mod, op_desc = stage.ops[op_idx], stage.op_descriptions[op_idx]; factor = DISCRETE_RESIZE_FACTORS[actions['target_resize_factor_idx'].item()]
                if abs(factor - 1.0) < 1e-6: return False
                new_op = resize_conv_output(op_mod, factor, self.device)
                if new_op is not op_mod: stage.ops[op_idx]=new_op; op_desc['out_channels']=new_op.out_channels; changed=True

        elif edit_type == EDIT_TYPE_ADD_CONV2D or edit_type == EDIT_TYPE_ADD_RELU:
            in_ch, in_sp = stage.get_current_out_properties()
            in_ch = max(1, in_ch)
            in_indices = [-1] if not stage.ops else [len(stage.ops)-1]
            op, desc = None, {}
            if edit_type == EDIT_TYPE_ADD_CONV2D:
                k, m = DISCRETE_KERNEL_SIZES[actions['target_conv_kernel_idx'].item()], DISCRETE_CH_MULT_ADD[actions['target_conv_ch_mult_idx'].item()]
                out_ch=max(1,int(round(in_ch*m)))
                op=nn.Conv2d(in_ch,out_ch,k,stride=1,padding=(k-1)//2,bias=False).to(self.device); nn.init.kaiming_normal_(op.weight,mode='fan_out',nonlinearity='relu')
                desc={'type':'conv2d','params':{'k':k,'mult':m},'out_channels':out_ch, 'out_spatial': in_sp, 'input_indices':in_indices}
            elif edit_type == EDIT_TYPE_ADD_RELU:
                op=nn.ReLU(inplace=False).to(self.device); desc={'type':'relu','out_channels':in_ch, 'out_spatial': in_sp, 'input_indices':in_indices}
            if op and stage.add_op(op,desc): changed=True

        elif edit_type == EDIT_TYPE_ADD_SKIP:
            source_op_idx = actions.get('source_op_idx', -1)
            dest_op_idx = actions.get('dest_op_idx', -1)

            if source_op_idx != -1 and dest_op_idx != -1:
                source_ch, _ = stage.get_op_output_properties(source_op_idx)
                dest_ch, dest_sp = stage.get_op_output_properties(dest_op_idx)

                projection = nn.Identity()
                if source_ch != dest_ch:
                    projection = nn.Sequential(
                        nn.Conv2d(source_ch, dest_ch, kernel_size=1, bias=False),
                        nn.BatchNorm2d(dest_ch)
                    ).to(self.device)

                add_op = AddWithProjection(projection)
                add_desc = {'type': 'add', 'out_channels': dest_ch, 'out_spatial': dest_sp, 'input_indices': [dest_op_idx, source_op_idx]}

                insert_at_idx = dest_op_idx + 1
                stage.add_op(add_op, add_desc, insert_at=insert_at_idx)

                # --- Robust Graph Rewiring ---
                # 1. Shift all indices that are affected by the insertion
                for op_idx_remap in range(len(stage.ops)):
                    if op_idx_remap == insert_at_idx: continue
                    remapped_indices = []
                    for input_idx in stage.op_descriptions[op_idx_remap]['input_indices']:
                        if input_idx >= insert_at_idx:
                            remapped_indices.append(input_idx + 1)
                        else:
                            remapped_indices.append(input_idx)
                    stage.op_descriptions[op_idx_remap]['input_indices'] = remapped_indices

                # 2. Find the op(s) that originally took the destination as input and rewire them to the new Add op
                for op_idx_remap in range(insert_at_idx + 1, len(stage.ops)):
                    remapped_indices = []
                    for input_idx in stage.op_descriptions[op_idx_remap]['input_indices']:
                        if input_idx == dest_op_idx + 1: # If it was pointing to the old destination (which is now shifted)
                            remapped_indices.append(insert_at_idx) # Point it to the new Add op
                        else:
                            remapped_indices.append(input_idx)
                    stage.op_descriptions[op_idx_remap]['input_indices'] = remapped_indices

                changed = True

        if changed: self._ensure_target_cnn_consistency()
        return changed

    def _apply_meta_self_edit(self, action):
        edit_type=action.item(); changed=False
        if edit_type==META_EDIT_DEEPEN_GNN: changed=self.meta_agent.deepen_gnn(device=self.device)
        elif edit_type==META_EDIT_WIDEN_GNN_HIDDEN: changed=self.meta_agent.widen_gnn_hidden_dim(factor=META_GNN_WIDEN_FACTOR,device=self.device)
        elif edit_type==META_EDIT_DEEPEN_MLP_HEAD:
            head_names=self.meta_agent.get_mlp_head_names()
            if head_names: changed=self.meta_agent.deepen_one_mlp_head(np.random.choice(head_names),device=self.device)
        if changed:
            print(f"MetaAgentGNN arch changed. New Params: {sum(p.numel() for p in self.meta_agent.parameters())}. Re-init optimizer.")
            del self.opt_meta; gc.collect(); torch.cuda.empty_cache()
            self.opt_meta=optim.Adam(self.meta_agent.parameters(),lr=META_LEARNING_RATE)
        return changed

    def _train_target_one_epoch(self, loader, optimizer, scheduler, name="Tr"):
        self.target_cnn.train()
        loss_sum, n_batches, correct, total = 0, 0, 0, 0

        data_iterator = itertools.islice(loader, BATCHES_PER_EPOCH) if BATCHES_PER_EPOCH is not None else loader

        for x,y in data_iterator:
            x,y=x.to(self.device),y.to(self.device)
            mixed_x, y_a, y_b, lam = self.mixup_data(x, y, alpha=0.4)
            y_a_one_hot, y_b_one_hot = F.one_hot(y_a, 10).float(), F.one_hot(y_b, 10).float()

            optimizer.zero_grad(set_to_none=True)
            with autocast(self.device.type,enabled=(self.device.type=='cuda')):
                logits=self.target_cnn(mixed_x)
                loss = self.mixup_criterion(logits, y_a_one_hot, y_b_one_hot, lam)

            if torch.isnan(loss) or torch.isinf(loss):
                continue

            self.amp_scaler.scale(loss).backward()
            self.amp_scaler.unscale_(optimizer)
            clip_grad_norm_(self.target_cnn.parameters(), MAX_GRAD_NORM)
            self.amp_scaler.step(optimizer)
            self.amp_scaler.update()

            loss_sum+=loss.item(); _,pred=logits.max(1); total+=y_a.size(0); correct+=pred.eq(y_a).sum().item(); n_batches+=1

        scheduler.step()
        return loss_sum/max(1,n_batches), correct/max(1,total)

    def _validate_target(self, loader):
        self.target_cnn.eval()
        loss_sum, correct, total, n_batches = 0,0,0,0
        criterion = nn.CrossEntropyLoss()

        data_iterator = itertools.islice(loader, BATCHES_PER_EPOCH) if BATCHES_PER_EPOCH is not None else loader

        with torch.no_grad():
            for x,y in data_iterator:
                x,y=x.to(self.device),y.to(self.device)
                logits=self.target_cnn(x); loss=criterion(logits,y)
                if torch.isnan(loss) or torch.isinf(loss): continue
                loss_sum+=loss.item(); _,pred=logits.max(1); total+=y.size(0); correct+=pred.eq(y).sum().item(); n_batches+=1
        return loss_sum/max(1,n_batches), correct/max(1,total)

    def train_loop(self, iterations=100):
        for itr in range(iterations):
            print(f"\n===== Iteration {itr+1}/{iterations} =====")
            print(f"Current MetaAgentGNN: GNN Layers={self.meta_agent.current_num_gnn_layers}, GNN Hidden={self.meta_agent.current_gnn_hidden_dim}, Params: {sum(p.numel() for p in self.meta_agent.parameters()):,}")
            self.sched_target = CosineAnnealingLR(self.opt_target, T_max=PRE_EPOCHS+POST_EPOCHS)

            for pre_ep in range(PRE_EPOCHS):
                self._train_target_one_epoch(self.train_loader, self.opt_target, self.sched_target, f"PreE{pre_ep+1}")
            val_loss_b, acc_b = self._validate_target(self.val_loader)
            print(f"PreVal: ValidL={val_loss_b:.4f}, ValidA={acc_b:.4f}")

            model_backup = copy.deepcopy(self.target_cnn)
            optimizer_state_backup = copy.deepcopy(self.opt_target.state_dict())

            graph, op_map = self._create_target_cnn_graph_data()
            target_params_M = sum(p.numel() for p in self.target_cnn.parameters() if p.requires_grad)/1e6
            norm_m_gl=self.meta_agent.current_num_gnn_layers / (MAX_GNN_LAYERS or self.meta_agent.current_num_gnn_layers + 1e-6)
            norm_m_gh=self.meta_agent.current_gnn_hidden_dim / (MAX_GNN_HIDDEN_DIM or self.meta_agent.current_gnn_hidden_dim + 1e-6)
            g_state=[val_loss_b,acc_b,target_params_M,norm_m_gl,norm_m_gh]; self.global_states_history_buffer.append(g_state)
            if len(self.global_states_history_buffer)>MAX_GLOBAL_HISTORY_LEN: self.global_states_history_buffer.pop(0)
            hist = list(self.global_states_history_buffer);
            while len(hist)<MAX_GLOBAL_HISTORY_LEN: hist.insert(0,[0.]*GLOBAL_SUMMARY_FEATURE_DIM)
            g_hist_flat=torch.tensor(hist,dtype=torch.float32,device=self.device).view(1,-1)

            actions = {}
            lp_t, en_t = 0.0, 0.0

            l_te, l_mse, val_p, fne, base_state_embed = self.meta_agent(graph, g_hist_flat)
            dist_te = Categorical(logits=l_te)
            s_te = dist_te.sample()
            actions['target_edit_type'] = s_te
            lp_t += dist_te.log_prob(s_te); en_t += dist_te.entropy().mean()
            edit_type = s_te.item()

            conditional_logits = self.meta_agent.get_conditional_logits(base_state_embed, s_te)
            l_ts = conditional_logits['stage']
            dist_ts = Categorical(logits=l_ts)
            s_ts = dist_ts.sample()
            actions['target_loc_stage'] = s_ts
            lp_t += dist_ts.log_prob(s_ts); en_t += dist_ts.entropy().mean()

            if edit_type == EDIT_TYPE_ADD_CONV2D:
                l_tk = conditional_logits['kernel']; dist_tk = Categorical(logits=l_tk); s_tk = dist_tk.sample()
                actions['target_conv_kernel_idx'] = s_tk
                lp_t += dist_tk.log_prob(s_tk); en_t += dist_tk.entropy().mean()

                l_tc = conditional_logits['ch_mult']; dist_tc = Categorical(logits=l_tc); s_tc = dist_tc.sample()
                actions['target_conv_ch_mult_idx'] = s_tc
                lp_t += dist_tc.log_prob(s_tc); en_t += dist_tc.entropy().mean()

            elif edit_type == EDIT_TYPE_RESIZE_CNN_CONV:
                stage=self.target_cnn.stages[s_ts.item()]; candidates=[]
                for oi,op in enumerate(stage.ops):
                    if isinstance(op, nn.Conv2d):
                        valid_idx = _valid_resize_indices(op.out_channels)
                        if valid_idx:
                            gid=op_map.get((s_ts.item(),oi),-1)
                            if gid!=-1 and gid<fne.size(0): candidates.append((oi,fne[gid],valid_idx))

                a_op_idx_rsz = -1
                l_tr = conditional_logits['resize_factor']
                dist_rf = Categorical(logits=l_tr)
                if candidates:
                    scores = self.meta_agent.head_resize_op_selector_scorer(torch.stack([e for _,e,_ in candidates])).squeeze(-1)
                    if scores.numel() > 0:
                        dist_co = Categorical(logits=scores); s_kth = dist_co.sample(); a_op_idx_rsz = candidates[s_kth.item()][0]
                        lp_t += dist_co.log_prob(s_kth); en_t += dist_co.entropy().mean()
                        valid_rf_idx = candidates[s_kth.item()][2]
                        masked_l_tr = _mask_logits(l_tr.squeeze(0), valid_rf_idx)
                        dist_rf = Categorical(logits=masked_l_tr if not torch.all(torch.isinf(masked_l_tr)) else l_tr)

                s_rf_idx = dist_rf.sample()
                lp_t += dist_rf.log_prob(s_rf_idx); en_t += dist_rf.entropy().mean()
                actions['target_resize_factor_idx'] = s_rf_idx
                actions['target_actual_op_idx_in_stage'] = a_op_idx_rsz

            elif edit_type == EDIT_TYPE_ADD_SKIP:
                stage = self.target_cnn.stages[s_ts.item()]
                valid_pairs = []
                for i in range(len(stage.ops)):
                    for j in range(i + 1, len(stage.ops)):
                        _, src_sp = stage.get_op_output_properties(i)
                        _, dest_sp = stage.get_op_output_properties(j)
                        if src_sp == dest_sp:
                            valid_pairs.append((i, j))

                if valid_pairs:
                    source_indices = torch.tensor([op_map[(s_ts.item(), p[0])] for p in valid_pairs], device=self.device)
                    dest_indices = torch.tensor([op_map[(s_ts.item(), p[1])] for p in valid_pairs], device=self.device)

                    source_scores = self.meta_agent.head_skip_source_scorer(fne[source_indices]).squeeze()
                    dest_scores = self.meta_agent.head_skip_destination_scorer(fne[dest_indices]).squeeze()

                    if source_scores.dim() == 0:
                        source_scores = source_scores.unsqueeze(0)
                        dest_scores = dest_scores.unsqueeze(0)

                    pair_scores = source_scores + dest_scores
                    dist_pair = Categorical(logits=pair_scores)
                    chosen_pair_idx = dist_pair.sample()

                    chosen_source_op, chosen_dest_op = valid_pairs[chosen_pair_idx.item()]
                    actions['source_op_idx'] = chosen_source_op
                    actions['dest_op_idx'] = chosen_dest_op
                    lp_t += dist_pair.log_prob(chosen_pair_idx); en_t += dist_pair.entropy()
                else:
                    actions['source_op_idx'] = -1; actions['dest_op_idx'] = -1

            valid_meta_actions = [i for i in range(NUM_META_SELF_EDIT_TYPES) if i not in _invalid_meta_indices(self.meta_agent)]
            if not valid_meta_actions: s_mse, lp_mse, en_mse = torch.tensor(META_EDIT_NONE, device=self.device), torch.tensor(0.0), torch.tensor(0.0)
            else:
                masked_l_mse = _mask_logits(l_mse.squeeze(0), valid_meta_actions)
                dist_mse = Categorical(logits=masked_l_mse if not torch.all(torch.isinf(masked_l_mse)) else l_mse)
                s_mse=dist_mse.sample(); lp_mse = dist_mse.log_prob(s_mse); en_mse = dist_mse.entropy().mean()

            log_parts = [f"TargEdit:Typ={edit_type},Stg={actions['target_loc_stage'].item()}"]
            if edit_type==EDIT_TYPE_ADD_CONV2D: log_parts.append(f"K={DISCRETE_KERNEL_SIZES[actions['target_conv_kernel_idx'].item()]},CHM={DISCRETE_CH_MULT_ADD[actions['target_conv_ch_mult_idx'].item()]}")
            elif edit_type==EDIT_TYPE_RESIZE_CNN_CONV: log_parts.append(f"Op={actions.get('target_actual_op_idx_in_stage',-1)},RszF={DISCRETE_RESIZE_FACTORS[actions.get('target_resize_factor_idx', 0).item()]}")
            elif edit_type==EDIT_TYPE_ADD_SKIP: log_parts.append(f"Src={actions.get('source_op_idx', -1)}->Dest={actions.get('dest_op_idx', -1)}")
            log_parts.append(f"| MetaSelfEdit:Typ={s_mse.item()}")
            print(" ".join(log_parts))

            t_changed = self._apply_target_cnn_edit(actions)
            if t_changed:
                print(f"  TargetCNN arch changed. New Params: {sum(p.numel() for p in self.target_cnn.parameters() if p.requires_grad):,}")
                del self.opt_target, self.sched_target; gc.collect(); torch.cuda.empty_cache()
                self.opt_target=optim.AdamW(self.target_cnn.parameters(),lr=LEARNING_RATE,weight_decay=1e-4)
                self.sched_target = CosineAnnealingLR(self.opt_target, T_max=PRE_EPOCHS+POST_EPOCHS)

            m_changed=False
            if (itr+1)%META_SELF_EDIT_INTERVAL==0 and s_mse.item()!=META_EDIT_NONE:
                m_changed=self._apply_meta_self_edit(s_mse)

            for post_ep in range(POST_EPOCHS):
                train_loss, train_acc = self._train_target_one_epoch(self.train_loader,self.opt_target, self.sched_target, f"PostE{post_ep+1}")
                print(f"  PostE{post_ep+1}: TrainL={train_loss:.4f}, TrainA={train_acc:.4f}")
            val_loss_a, acc_a = self._validate_target(self.val_loader)
            print(f"PostVal: ValidL={val_loss_a:.4f}, ValidA={acc_a:.4f}")

            if acc_a == 0.0 and val_loss_b > 0:
                print("\nFATAL ERROR: Training has collapsed, validation accuracy is zero.")
                raise RuntimeError("Training collapsed, accuracy is zero.")

            was_reverted = False
            if acc_a < (acc_b - 0.08):
                print(f"  !!! ACCURACY DROP > 8% ({acc_b:.4f} -> {acc_a:.4f}). REVERTING MODEL. !!!")
                self.target_cnn = model_backup
                self.opt_target = optim.AdamW(self.target_cnn.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
                self.opt_target.load_state_dict(optimizer_state_backup)
                self.sched_target = CosineAnnealingLR(self.opt_target, T_max=PRE_EPOCHS+POST_EPOCHS)
                acc_a = acc_b; val_loss_a = val_loss_b
                was_reverted = True

            reward=(acc_a-acc_b)*100
            if was_reverted: reward = -10.0
            else:
                if not t_changed: reward-=2
                if m_changed: reward+=1
            print(f"Reward:{reward:.2f}")

            advantage = reward - val_p.detach().squeeze().item()
            actor_loss = -(lp_t+lp_mse)*advantage
            critic_loss = F.mse_loss(val_p.squeeze(), torch.tensor(reward, device=self.device, dtype=torch.float32))

            meta_loss=actor_loss.mean()+ 0.5 * critic_loss - 0.05*(en_t+en_mse)
            if torch.isnan(meta_loss)or torch.isinf(meta_loss):
                print("MetaLoss NaN/Inf! Skipping meta-update.")
                del model_backup, optimizer_state_backup; gc.collect()
                continue

            self.opt_meta.zero_grad(); meta_loss.backward(); clip_grad_norm_(self.meta_agent.parameters(),MAX_GRAD_NORM); self.opt_meta.step()
            print(f"MetaL:{meta_loss.item():.4f}(A:{actor_loss.mean().item():.4f},C:{critic_loss.item():.4f},E:{(en_t+en_mse).item():.4f})")

            del model_backup, optimizer_state_backup; gc.collect()


if __name__ == '__main__':
    if not PYG_AVAILABLE:
        print("Exiting: PyTorch Geometric required."); exit()
    torch.manual_seed(42); np.random.seed(42)
    print(f"Using device: {DEVICE}")
    try:
        deiti_system = DEITI()
        print(f"Init TargetCNN P: {sum(p.numel() for p in deiti_system.target_cnn.parameters() if p.requires_grad):,}")
        print(f"Init MetaAgentGNN: L={deiti_system.meta_agent.current_num_gnn_layers},H={deiti_system.meta_agent.current_gnn_hidden_dim},P={sum(p.numel() for p in deiti_system.meta_agent.parameters()):,}")
        print("\n--- Initial Validation ---")
        initial_loss,initial_acc=deiti_system._validate_target(deiti_system.val_loader);print(f"InitVal: L={initial_loss:.4f},A={initial_acc:.4f}")
        deiti_system.train_loop(iterations=200)
        print("\n===== Search Finished =====")
        print(f"Final TargetCNN P: {sum(p.numel() for p in deiti_system.target_cnn.parameters() if p.requires_grad):,}")
        print(f"Final MetaAgentGNN: L={deiti_system.meta_agent.current_num_gnn_layers},H={deiti_system.meta_agent.current_gnn_hidden_dim},P={sum(p.numel() for p in deiti_system.meta_agent.parameters()):,}")
    except Exception as e:
        print(f"\n\nFATAL RUNTIME ERROR: {e}")
        print("Stopping execution to release Colab resources.")
        raise e
# Out:
# Enabling TensorFloat32 matmul precision for supported GPU.
# Using device: cuda
# Using 4 workers for data loading.
# Init TargetCNN P: 24,122
# Init MetaAgentGNN: L=2,H=32,P=3,181
#
# --- Initial Validation ---
# InitVal: L=2.3045,A=0.0906
#
# ===== Iteration 1/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.9505, ValidA=0.3002
# TargEdit:Typ=2,Stg=1 Op=0,RszF=4.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 93,242
#   PostE1: TrainL=2.1243, TrainA=0.1776
#   PostE2: TrainL=2.0940, TrainA=0.1876
#   PostE3: TrainL=2.0640, TrainA=0.1922
#   PostE4: TrainL=2.0444, TrainA=0.2163
#   PostE5: TrainL=2.0182, TrainA=0.2299
#   PostE6: TrainL=2.0133, TrainA=0.2290
#   PostE7: TrainL=1.9878, TrainA=0.2257
#   PostE8: TrainL=1.9873, TrainA=0.2337
#   PostE9: TrainL=1.9726, TrainA=0.2375
#   PostE10: TrainL=1.9592, TrainA=0.2637
# PostVal: ValidL=1.5349, ValidA=0.4842
# Reward:18.40
# MetaL:250.3989(A:87.5769,C:326.2265,E:5.8258)
#
# ===== Iteration 2/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.5321, ValidA=0.4848
# TargEdit:Typ=0,Stg=1 K=1,CHM=0.5 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 64,570
#   PostE1: TrainL=2.0927, TrainA=0.2051
#   PostE2: TrainL=2.0034, TrainA=0.2370
#   PostE3: TrainL=1.9756, TrainA=0.2524
#   PostE4: TrainL=1.9549, TrainA=0.2505
#   PostE5: TrainL=1.9442, TrainA=0.2616
#   PostE6: TrainL=1.9173, TrainA=0.2895
#   PostE7: TrainL=1.9236, TrainA=0.2548
#   PostE8: TrainL=1.9215, TrainA=0.2705
#   PostE9: TrainL=1.8753, TrainA=0.2758
#   PostE10: TrainL=1.8923, TrainA=0.2670
# PostVal: ValidL=1.3737, ValidA=0.5454
# Reward:6.06
# MetaL:48.9663(A:32.0470,C:34.3900,E:5.5143)
#
# ===== Iteration 3/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.3687, ValidA=0.5552
# TargEdit:Typ=3,Stg=2 Src=0->Dest=1 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 64,570
#   PostE1: TrainL=2.0966, TrainA=0.2483
#   PostE2: TrainL=1.9180, TrainA=0.2629
#   PostE3: TrainL=1.8936, TrainA=0.2738
#   PostE4: TrainL=1.8897, TrainA=0.2506
#   PostE5: TrainL=1.8809, TrainA=0.2776
#   PostE6: TrainL=1.8586, TrainA=0.2814
#   PostE7: TrainL=1.8479, TrainA=0.3169
#   PostE8: TrainL=1.8503, TrainA=0.3022
#   PostE9: TrainL=1.8256, TrainA=0.2798
#   PostE10: TrainL=1.8685, TrainA=0.2829
# PostVal: ValidL=1.2770, ValidA=0.5795
# Reward:2.43
# MetaL:8.0024(A:6.4048,C:3.5713,E:3.7605)
#
# ===== Iteration 4/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.2711, ValidA=0.5869
# TargEdit:Typ=1,Stg=2 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 64,570
#   PostE1: TrainL=1.8703, TrainA=0.3026
#   PostE2: TrainL=1.8527, TrainA=0.2937
#   PostE3: TrainL=1.8213, TrainA=0.2971
#   PostE4: TrainL=1.8440, TrainA=0.2934
#   PostE5: TrainL=1.8143, TrainA=0.3020
#   PostE6: TrainL=1.8360, TrainA=0.2788
#   PostE7: TrainL=1.8069, TrainA=0.3092
#   PostE8: TrainL=1.8085, TrainA=0.3044
#   PostE9: TrainL=1.8039, TrainA=0.2994
#   PostE10: TrainL=1.7603, TrainA=0.3307
# PostVal: ValidL=1.1594, ValidA=0.6301
# Reward:4.32
# MetaL:19.0384(A:13.0496,C:12.3520,E:3.7453)
#
# ===== Iteration 5/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.1632, ValidA=0.6252
# TargEdit:Typ=2,Stg=1 Op=0,RszF=0.5 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 51,258
#   PostE1: TrainL=1.9224, TrainA=0.2776
#   PostE2: TrainL=1.8532, TrainA=0.2866
#   PostE3: TrainL=1.8201, TrainA=0.3172
#   PostE4: TrainL=1.8041, TrainA=0.2856
#   PostE5: TrainL=1.7852, TrainA=0.3207
#   PostE6: TrainL=1.8138, TrainA=0.3055
#   PostE7: TrainL=1.7750, TrainA=0.2998
#   PostE8: TrainL=1.7835, TrainA=0.3174
#   PostE9: TrainL=1.7734, TrainA=0.3101
#   PostE10: TrainL=1.7761, TrainA=0.3322
# PostVal: ValidL=1.1605, ValidA=0.6235
# Reward:-0.17
# MetaL:-3.7550(A:-3.8428,C:0.7982,E:6.2249)
#
# ===== Iteration 6/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.1558, ValidA=0.6308
# TargEdit:Typ=2,Stg=1 Op=3,RszF=0.75 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 41,018
#   PostE1: TrainL=1.8414, TrainA=0.2900
#   PostE2: TrainL=1.7924, TrainA=0.3137
#   PostE3: TrainL=1.7958, TrainA=0.2704
#   PostE4: TrainL=1.8165, TrainA=0.3086
#   PostE5: TrainL=1.7763, TrainA=0.3331
#   PostE6: TrainL=1.7784, TrainA=0.3295
#   PostE7: TrainL=1.7735, TrainA=0.3079
#   PostE8: TrainL=1.7921, TrainA=0.3265
#   PostE9: TrainL=1.7814, TrainA=0.3095
#   PostE10: TrainL=1.7588, TrainA=0.2973
# PostVal: ValidL=1.1284, ValidA=0.6411
# Reward:1.03
# MetaL:1.5042(A:1.7581,C:0.1199,E:6.2765)
#
# ===== Iteration 7/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.1207, ValidA=0.6443
# TargEdit:Typ=1,Stg=2 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 41,018
#   PostE1: TrainL=1.7952, TrainA=0.3353
#   PostE2: TrainL=1.7544, TrainA=0.3127
#   PostE3: TrainL=1.7723, TrainA=0.3372
#   PostE4: TrainL=1.7560, TrainA=0.3092
#   PostE5: TrainL=1.7821, TrainA=0.2923
#   PostE6: TrainL=1.7809, TrainA=0.3325
#   PostE7: TrainL=1.7558, TrainA=0.3451
#   PostE8: TrainL=1.7734, TrainA=0.3007
#   PostE9: TrainL=1.7471, TrainA=0.3339
#   PostE10: TrainL=1.7684, TrainA=0.3102
# PostVal: ValidL=1.0840, ValidA=0.6607
# Reward:1.64
# MetaL:4.0426(A:3.7566,C:0.9453,E:3.7343)
#
# ===== Iteration 8/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0779, ValidA=0.6616
# TargEdit:Typ=1,Stg=2 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 41,018
#   PostE1: TrainL=1.7747, TrainA=0.2981
#   PostE2: TrainL=1.7419, TrainA=0.3002
#   PostE3: TrainL=1.8044, TrainA=0.3055
#   PostE4: TrainL=1.7109, TrainA=0.2743
#   PostE5: TrainL=1.7327, TrainA=0.3222
#   PostE6: TrainL=1.7456, TrainA=0.3241
#   PostE7: TrainL=1.7532, TrainA=0.3591
#   PostE8: TrainL=1.7305, TrainA=0.3534
#   PostE9: TrainL=1.7353, TrainA=0.3456
#   PostE10: TrainL=1.7218, TrainA=0.3646
# PostVal: ValidL=1.0387, ValidA=0.6708
# Reward:0.92
# MetaL:0.8381(A:0.9915,C:0.0675,E:3.7426)
#
# ===== Iteration 9/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0387, ValidA=0.6724
# TargEdit:Typ=0,Stg=0 K=1,CHM=0.5 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 36,538
#   PostE1: TrainL=3.5243, TrainA=0.1581
#   PostE2: TrainL=2.0760, TrainA=0.2212
#   PostE3: TrainL=2.0184, TrainA=0.2291
#   PostE4: TrainL=1.9832, TrainA=0.2399
#   PostE5: TrainL=1.9344, TrainA=0.2580
#   PostE6: TrainL=1.9445, TrainA=0.2775
#   PostE7: TrainL=1.9171, TrainA=0.2787
#   PostE8: TrainL=1.9034, TrainA=0.2854
#   PostE9: TrainL=1.9049, TrainA=0.2742
#   PostE10: TrainL=1.9035, TrainA=0.2561
# PostVal: ValidL=1.3553, ValidA=0.5578
#   !!! ACCURACY DROP > 8% (0.6724 -> 0.5578). REVERTING MODEL. !!!
# Reward:-10.00
# MetaL:-9.0424(A:-65.6354,C:113.7353,E:5.4934)
#
# ===== Iteration 10/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0403, ValidA=0.6748
# TargEdit:Typ=2,Stg=0 Op=0,RszF=1.25 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 43,430
#   PostE1: TrainL=1.7582, TrainA=0.3317
#   PostE2: TrainL=1.7313, TrainA=0.3170
#   PostE3: TrainL=1.7449, TrainA=0.3264
#   PostE4: TrainL=1.7358, TrainA=0.3069
#   PostE5: TrainL=1.7432, TrainA=0.3702
#   PostE6: TrainL=1.6624, TrainA=0.3206
#   PostE7: TrainL=1.7440, TrainA=0.3532
#   PostE8: TrainL=1.6931, TrainA=0.3357
#   PostE9: TrainL=1.7392, TrainA=0.3125
#   PostE10: TrainL=1.7103, TrainA=0.3187
# PostVal: ValidL=1.0009, ValidA=0.6876
# Reward:1.28
# MetaL:3.6751(A:3.7691,C:0.3749,E:5.6296)
#
# ===== Iteration 11/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0010, ValidA=0.6893
# TargEdit:Typ=0,Stg=1 K=3,CHM=0.5 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 39,974
#   PostE1: TrainL=2.0469, TrainA=0.2431
#   PostE2: TrainL=1.8551, TrainA=0.3009
#   PostE3: TrainL=1.7947, TrainA=0.3054
#   PostE4: TrainL=1.7452, TrainA=0.3385
#   PostE5: TrainL=1.7816, TrainA=0.3200
#   PostE6: TrainL=1.7509, TrainA=0.3131
#   PostE7: TrainL=1.7028, TrainA=0.3111
#   PostE8: TrainL=1.7211, TrainA=0.3108
#   PostE9: TrainL=1.7482, TrainA=0.3441
#   PostE10: TrainL=1.7196, TrainA=0.3208
# PostVal: ValidL=1.0226, ValidA=0.6809
# Reward:-0.84
# MetaL:-8.2388(A:-9.1022,C:2.2766,E:5.4964)
#
# ===== Iteration 12/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0117, ValidA=0.6849
# TargEdit:Typ=2,Stg=0 Op=0,RszF=0.5 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 33,944
#   PostE1: TrainL=1.9073, TrainA=0.2907
#   PostE2: TrainL=1.7888, TrainA=0.3290
#   PostE3: TrainL=1.8117, TrainA=0.3048
#   PostE4: TrainL=1.7785, TrainA=0.3075
#   PostE5: TrainL=1.7612, TrainA=0.2876
#   PostE6: TrainL=1.7810, TrainA=0.2824
#   PostE7: TrainL=1.7653, TrainA=0.3349
#   PostE8: TrainL=1.7258, TrainA=0.3455
#   PostE9: TrainL=1.7484, TrainA=0.3512
#   PostE10: TrainL=1.7427, TrainA=0.3183
# PostVal: ValidL=1.0447, ValidA=0.6735
# Reward:-1.14
# MetaL:-7.4450(A:-8.8057,C:3.2856,E:5.6425)
#
# ===== Iteration 13/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=1.0325, ValidA=0.6757
# TargEdit:Typ=3,Stg=1 Src=3->Dest=4 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 35,144
#   PostE1: TrainL=1.7808, TrainA=0.3198
#   PostE2: TrainL=1.7334, TrainA=0.3136
#   PostE3: TrainL=1.7354, TrainA=0.3453
#   PostE4: TrainL=1.6940, TrainA=0.2831
#   PostE5: TrainL=1.6917, TrainA=0.3323
#   PostE6: TrainL=1.6933, TrainA=0.3361
#   PostE7: TrainL=1.7198, TrainA=0.3490
#   PostE8: TrainL=1.6769, TrainA=0.3553
#   PostE9: TrainL=1.7141, TrainA=0.3000
#   PostE10: TrainL=1.7232, TrainA=0.3456
# PostVal: ValidL=0.9714, ValidA=0.6994
# Reward:2.37
# MetaL:9.3391(A:8.1487,C:2.8993,E:5.1836)
#
# ===== Iteration 14/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.9532, ValidA=0.7035
# TargEdit:Typ=3,Stg=2 Src=1->Dest=4 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 35,144
#   PostE1: TrainL=1.7508, TrainA=0.3036
#   PostE2: TrainL=1.7184, TrainA=0.2967
#   PostE3: TrainL=1.7053, TrainA=0.3352
#   PostE4: TrainL=1.7131, TrainA=0.3605
#   PostE5: TrainL=1.7036, TrainA=0.3107
#   PostE6: TrainL=1.7007, TrainA=0.3449
#   PostE7: TrainL=1.7197, TrainA=0.3265
#   PostE8: TrainL=1.6984, TrainA=0.3619
#   PostE9: TrainL=1.6613, TrainA=0.3288
#   PostE10: TrainL=1.6837, TrainA=0.3202
# PostVal: ValidL=0.9633, ValidA=0.7113
# Reward:0.78
# MetaL:0.4537(A:0.7716,C:0.0145,E:6.5025)
#
# ===== Iteration 15/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.9439, ValidA=0.7100
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 35,144
#   PostE1: TrainL=1.8292, TrainA=0.3033
#   PostE2: TrainL=1.7749, TrainA=0.3045
#   PostE3: TrainL=1.7327, TrainA=0.3526
#   PostE4: TrainL=1.6887, TrainA=0.3318
#   PostE5: TrainL=1.6975, TrainA=0.3529
#   PostE6: TrainL=1.7057, TrainA=0.3293
#   PostE7: TrainL=1.7184, TrainA=0.2940
#   PostE8: TrainL=1.6775, TrainA=0.3237
#   PostE9: TrainL=1.6819, TrainA=0.3520
#   PostE10: TrainL=1.6489, TrainA=0.3926
# PostVal: ValidL=0.9443, ValidA=0.7056
# Reward:-0.44
# MetaL:-3.2943(A:-3.7264,C:1.2394,E:3.7516)
#
# ===== Iteration 16/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.9581, ValidA=0.7035
# TargEdit:Typ=0,Stg=2 K=1,CHM=2.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 43,976
#   PostE1: TrainL=1.9605, TrainA=0.2762
#   PostE2: TrainL=1.8265, TrainA=0.2971
#   PostE3: TrainL=1.7253, TrainA=0.2962
#   PostE4: TrainL=1.7429, TrainA=0.3297
#   PostE5: TrainL=1.7089, TrainA=0.3396
#   PostE6: TrainL=1.6852, TrainA=0.3646
#   PostE7: TrainL=1.6611, TrainA=0.3489
#   PostE8: TrainL=1.6416, TrainA=0.3391
#   PostE9: TrainL=1.6763, TrainA=0.3840
#   PostE10: TrainL=1.6732, TrainA=0.3543
# PostVal: ValidL=0.9349, ValidA=0.7087
# Reward:0.52
# MetaL:-1.0104(A:-0.7471,C:0.0223,E:5.4885)
#
# ===== Iteration 17/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.9304, ValidA=0.7091
# TargEdit:Typ=2,Stg=1 Op=3,RszF=0.75 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 40,328
#   PostE1: TrainL=1.7690, TrainA=0.3037
#   PostE2: TrainL=1.7050, TrainA=0.2964
#   PostE3: TrainL=1.7280, TrainA=0.3194
#   PostE4: TrainL=1.6645, TrainA=0.3302
#   PostE5: TrainL=1.6856, TrainA=0.3358
#   PostE6: TrainL=1.6966, TrainA=0.3524
#   PostE7: TrainL=1.6965, TrainA=0.3137
#   PostE8: TrainL=1.7039, TrainA=0.3427
#   PostE9: TrainL=1.6907, TrainA=0.3683
#   PostE10: TrainL=1.6770, TrainA=0.3516
# PostVal: ValidL=0.9094, ValidA=0.7187
# Reward:0.96
# MetaL:1.3579(A:1.6511,C:0.0888,E:6.7511)
#
# ===== Iteration 18/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.9041, ValidA=0.7188
# TargEdit:Typ=2,Stg=1 Op=3,RszF=1.5 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 45,800
#   PostE1: TrainL=1.6854, TrainA=0.3454
#   PostE2: TrainL=1.6928, TrainA=0.3471
#   PostE3: TrainL=1.6832, TrainA=0.3694
#   PostE4: TrainL=1.6471, TrainA=0.3527
#   PostE5: TrainL=1.6711, TrainA=0.3356
#   PostE6: TrainL=1.6543, TrainA=0.3575
#   PostE7: TrainL=1.6680, TrainA=0.3167
#   PostE8: TrainL=1.6291, TrainA=0.3667
#   PostE9: TrainL=1.6236, TrainA=0.3303
#   PostE10: TrainL=1.6747, TrainA=0.3520
# PostVal: ValidL=0.8888, ValidA=0.7278
# Reward:0.90
# MetaL:1.2584(A:1.5688,C:0.0550,E:6.7578)
#
# ===== Iteration 19/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.8790, ValidA=0.7272
# TargEdit:Typ=2,Stg=2 Op=7,RszF=0.25 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 38,696
#   PostE1: TrainL=1.9329, TrainA=0.2395
#   PostE2: TrainL=1.7448, TrainA=0.3090
#   PostE3: TrainL=1.7326, TrainA=0.3391
#   PostE4: TrainL=1.7117, TrainA=0.3362
#   PostE5: TrainL=1.6720, TrainA=0.2981
#   PostE6: TrainL=1.6199, TrainA=0.3453
#   PostE7: TrainL=1.6257, TrainA=0.3720
#   PostE8: TrainL=1.6705, TrainA=0.3499
#   PostE9: TrainL=1.6282, TrainA=0.4129
#   PostE10: TrainL=1.6345, TrainA=0.3624
# PostVal: ValidL=0.9192, ValidA=0.7132
# Reward:-1.40
# MetaL:-12.6427(A:-14.4684,C:4.2866,E:6.3533)
#
# ===== Iteration 20/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=32, Params: 3,181
# PreVal: ValidL=0.8981, ValidA=0.7176
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 38,696
#   Widening MetaAgentGNN: GNN Hidden Dim 32 -> 64
# MetaAgentGNN arch changed. New Params: 7437. Re-init optimizer.
#   PostE1: TrainL=1.7050, TrainA=0.3338
#   PostE2: TrainL=1.7303, TrainA=0.3421
#   PostE3: TrainL=1.6825, TrainA=0.3842
#   PostE4: TrainL=1.6575, TrainA=0.3394
#   PostE5: TrainL=1.6371, TrainA=0.3605
#   PostE6: TrainL=1.6656, TrainA=0.2998
#   PostE7: TrainL=1.6201, TrainA=0.3588
#   PostE8: TrainL=1.6356, TrainA=0.3223
#   PostE9: TrainL=1.6405, TrainA=0.3359
#   PostE10: TrainL=1.6729, TrainA=0.3477
# PostVal: ValidL=0.8862, ValidA=0.7334
# Reward:2.58
# MetaL:10.2768(A:8.6400,C:3.6490,E:3.7552)
#
# ===== Iteration 21/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,437
# PreVal: ValidL=0.8752, ValidA=0.7323
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 38,696
#   PostE1: TrainL=1.6890, TrainA=0.3329
#   PostE2: TrainL=1.6086, TrainA=0.3384
#   PostE3: TrainL=1.6593, TrainA=0.3497
#   PostE4: TrainL=1.6496, TrainA=0.3319
#   PostE5: TrainL=1.6601, TrainA=0.3114
#   PostE6: TrainL=1.6029, TrainA=0.3898
#   PostE7: TrainL=1.6659, TrainA=0.3483
#   PostE8: TrainL=1.6345, TrainA=0.3576
#   PostE9: TrainL=1.6173, TrainA=0.3889
#   PostE10: TrainL=1.6206, TrainA=0.3117
# PostVal: ValidL=0.8537, ValidA=0.7475
# Reward:1.52
# MetaL:5.0014(A:4.2933,C:1.7950,E:3.7884)
#
# ===== Iteration 22/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,437
# PreVal: ValidL=0.8644, ValidA=0.7439
# TargEdit:Typ=0,Stg=2 K=3,CHM=1.0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 47,912
#   PostE1: TrainL=1.7764, TrainA=0.3169
#   PostE2: TrainL=1.6848, TrainA=0.3496
#   PostE3: TrainL=1.6720, TrainA=0.3502
#   PostE4: TrainL=1.6421, TrainA=0.3068
#   PostE5: TrainL=1.6188, TrainA=0.3837
#   PostE6: TrainL=1.6545, TrainA=0.3268
#   PostE7: TrainL=1.6448, TrainA=0.3792
#   PostE8: TrainL=1.6368, TrainA=0.3507
#   PostE9: TrainL=1.6075, TrainA=0.3640
#   PostE10: TrainL=1.6400, TrainA=0.3518
# PostVal: ValidL=0.8369, ValidA=0.7521
# Reward:0.82
# MetaL:3.4155(A:3.5012,C:0.3800,E:5.5154)
#
# ===== Iteration 23/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,437
# PreVal: ValidL=0.8141, ValidA=0.7526
# TargEdit:Typ=2,Stg=0 Op=0,RszF=0.25 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 43,088
#   PostE1: TrainL=2.2769, TrainA=0.1828
#   PostE2: TrainL=2.0527, TrainA=0.2067
#   PostE3: TrainL=1.9870, TrainA=0.2198
#   PostE4: TrainL=1.9728, TrainA=0.2365
#   PostE5: TrainL=1.9561, TrainA=0.2678
#   PostE6: TrainL=1.9424, TrainA=0.2545
#   PostE7: TrainL=1.9164, TrainA=0.2569
#   PostE8: TrainL=1.9066, TrainA=0.2566
#   PostE9: TrainL=1.9241, TrainA=0.2862
#   PostE10: TrainL=1.8895, TrainA=0.2576
# PostVal: ValidL=1.3281, ValidA=0.5724
#   !!! ACCURACY DROP > 8% (0.7526 -> 0.5724). REVERTING MODEL. !!!
# Reward:-10.00
# MetaL:-14.3487(A:-66.4425,C:104.7564,E:5.6865)
#
# ===== Iteration 24/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,437
# PreVal: ValidL=0.8434, ValidA=0.7493
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 47,912
#   PostE1: TrainL=1.6531, TrainA=0.3761
#   PostE2: TrainL=1.6740, TrainA=0.3294
#   PostE3: TrainL=1.5931, TrainA=0.3298
#   PostE4: TrainL=1.6373, TrainA=0.3522
#   PostE5: TrainL=1.6207, TrainA=0.4068
#   PostE6: TrainL=1.6187, TrainA=0.3758
#   PostE7: TrainL=1.6018, TrainA=0.3590
#   PostE8: TrainL=1.6440, TrainA=0.3670
#   PostE9: TrainL=1.6385, TrainA=0.3501
#   PostE10: TrainL=1.6230, TrainA=0.3482
# PostVal: ValidL=0.8189, ValidA=0.7502
# Reward:0.09
# MetaL:-0.6555(A:-0.4787,C:0.0231,E:3.7672)
#
# ===== Iteration 25/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,437
# PreVal: ValidL=0.8191, ValidA=0.7551
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 47,912
#   Deepened MLP head 'head_target_conv_ch_mult' (Linear -> Sequential)
# MetaAgentGNN arch changed. New Params: 7449. Re-init optimizer.
#   PostE1: TrainL=1.6534, TrainA=0.3385
#   PostE2: TrainL=1.6127, TrainA=0.3817
#   PostE3: TrainL=1.6383, TrainA=0.3684
#   PostE4: TrainL=1.6196, TrainA=0.3464
#   PostE5: TrainL=1.6207, TrainA=0.3682
#   PostE6: TrainL=1.5962, TrainA=0.3304
#   PostE7: TrainL=1.6179, TrainA=0.3886
#   PostE8: TrainL=1.6266, TrainA=0.3728
#   PostE9: TrainL=1.6169, TrainA=0.3561
#   PostE10: TrainL=1.6005, TrainA=0.3724
# PostVal: ValidL=0.8344, ValidA=0.7526
# Reward:0.75
# MetaL:1.4584(A:1.5204,C:0.2527,E:3.7660)
#
# ===== Iteration 26/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.7959, ValidA=0.7610
# TargEdit:Typ=0,Stg=0 K=3,CHM=1.0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 48,812
#   PostE1: TrainL=3.4376, TrainA=0.1779
#   PostE2: TrainL=2.0081, TrainA=0.2196
#   PostE3: TrainL=1.9446, TrainA=0.2451
#   PostE4: TrainL=1.9074, TrainA=0.2874
#   PostE5: TrainL=1.8827, TrainA=0.2605
#   PostE6: TrainL=1.8745, TrainA=0.2750
#   PostE7: TrainL=1.8285, TrainA=0.2865
#   PostE8: TrainL=1.8350, TrainA=0.2666
#   PostE9: TrainL=1.8316, TrainA=0.2926
#   PostE10: TrainL=1.7988, TrainA=0.3173
# PostVal: ValidL=1.2095, ValidA=0.6042
#   !!! ACCURACY DROP > 8% (0.7610 -> 0.6042). REVERTING MODEL. !!!
# Reward:-10.00
# MetaL:0.8872(A:-51.5835,C:105.4926,E:5.5127)
#
# ===== Iteration 27/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.8051, ValidA=0.7607
# TargEdit:Typ=0,Stg=2 K=3,CHM=2.0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 66,664
#   PostE1: TrainL=1.7133, TrainA=0.3227
#   PostE2: TrainL=1.6649, TrainA=0.3205
#   PostE3: TrainL=1.6505, TrainA=0.3421
#   PostE4: TrainL=1.5896, TrainA=0.3917
#   PostE5: TrainL=1.6104, TrainA=0.3373
#   PostE6: TrainL=1.5916, TrainA=0.3729
#   PostE7: TrainL=1.5828, TrainA=0.3999
#   PostE8: TrainL=1.6350, TrainA=0.3862
#   PostE9: TrainL=1.5896, TrainA=0.3538
#   PostE10: TrainL=1.5996, TrainA=0.3630
# PostVal: ValidL=0.8128, ValidA=0.7626
# Reward:0.19
# MetaL:-0.7875(A:-0.5154,C:0.0070,E:5.5125)
#
# ===== Iteration 28/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.7723, ValidA=0.7667
# TargEdit:Typ=0,Stg=1 K=3,CHM=1.0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 71,848
#   PostE1: TrainL=2.1916, TrainA=0.2368
#   PostE2: TrainL=1.7819, TrainA=0.3082
#   PostE3: TrainL=1.7699, TrainA=0.2819
#   PostE4: TrainL=1.7020, TrainA=0.2916
#   PostE5: TrainL=1.6649, TrainA=0.3267
#   PostE6: TrainL=1.6904, TrainA=0.3218
#   PostE7: TrainL=1.6840, TrainA=0.3512
#   PostE8: TrainL=1.6498, TrainA=0.3402
#   PostE9: TrainL=1.6158, TrainA=0.3777
#   PostE10: TrainL=1.6583, TrainA=0.3972
# PostVal: ValidL=0.9003, ValidA=0.7225
# Reward:-4.42
# MetaL:-14.3141(A:-25.0006,C:21.9237,E:5.5074)
#
# ===== Iteration 29/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.9231, ValidA=0.7210
# TargEdit:Typ=0,Stg=1 K=1,CHM=2.0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 86,824
#   PostE1: TrainL=2.0073, TrainA=0.2254
#   PostE2: TrainL=1.7807, TrainA=0.3054
#   PostE3: TrainL=1.7335, TrainA=0.3183
#   PostE4: TrainL=1.7017, TrainA=0.3372
#   PostE5: TrainL=1.6992, TrainA=0.3718
#   PostE6: TrainL=1.6868, TrainA=0.3058
#   PostE7: TrainL=1.6261, TrainA=0.3482
#   PostE8: TrainL=1.6297, TrainA=0.3658
#   PostE9: TrainL=1.6476, TrainA=0.3669
#   PostE10: TrainL=1.6485, TrainA=0.3640
# PostVal: ValidL=0.8737, ValidA=0.7267
# Reward:0.57
# MetaL:1.7428(A:1.9636,C:0.1083,E:5.4990)
#
# ===== Iteration 30/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.8740, ValidA=0.7290
# TargEdit:Typ=1,Stg=2 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 86,824
#   PostE1: TrainL=1.6914, TrainA=0.3445
#   PostE2: TrainL=1.6520, TrainA=0.3420
#   PostE3: TrainL=1.6476, TrainA=0.3292
#   PostE4: TrainL=1.6364, TrainA=0.4071
#   PostE5: TrainL=1.6043, TrainA=0.3299
#   PostE6: TrainL=1.6320, TrainA=0.3485
#   PostE7: TrainL=1.6318, TrainA=0.3375
#   PostE8: TrainL=1.5948, TrainA=0.3484
#   PostE9: TrainL=1.5653, TrainA=0.3871
#   PostE10: TrainL=1.5596, TrainA=0.3617
# PostVal: ValidL=0.8256, ValidA=0.7534
# Reward:2.44
# MetaL:11.2717(A:9.0449,C:4.8274,E:3.7384)
#
# ===== Iteration 31/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.8093, ValidA=0.7533
# TargEdit:Typ=2,Stg=0 Op=0,RszF=1.5 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 89,839
#   PostE1: TrainL=1.6830, TrainA=0.3688
#   PostE2: TrainL=1.6216, TrainA=0.3566
#   PostE3: TrainL=1.6685, TrainA=0.3760
#   PostE4: TrainL=1.5863, TrainA=0.3560
#   PostE5: TrainL=1.6221, TrainA=0.3661
#   PostE6: TrainL=1.5977, TrainA=0.4356
#   PostE7: TrainL=1.5524, TrainA=0.3743
#   PostE8: TrainL=1.5727, TrainA=0.3692
#   PostE9: TrainL=1.6183, TrainA=0.3895
#   PostE10: TrainL=1.5855, TrainA=0.3929
# PostVal: ValidL=0.8197, ValidA=0.7623
# Reward:0.90
# MetaL:3.6205(A:3.6775,C:0.4551,E:5.6893)
#
# ===== Iteration 32/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.8279, ValidA=0.7658
# TargEdit:Typ=3,Stg=0 Src=2->Dest=3 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 89,839
#   PostE1: TrainL=1.6436, TrainA=0.3331
#   PostE2: TrainL=1.5970, TrainA=0.3768
#   PostE3: TrainL=1.6134, TrainA=0.3520
#   PostE4: TrainL=1.5748, TrainA=0.3521
#   PostE5: TrainL=1.5794, TrainA=0.3618
#   PostE6: TrainL=1.5970, TrainA=0.3972
#   PostE7: TrainL=1.5973, TrainA=0.3507
#   PostE8: TrainL=1.5702, TrainA=0.3908
#   PostE9: TrainL=1.5643, TrainA=0.3535
#   PostE10: TrainL=1.5162, TrainA=0.3759
# PostVal: ValidL=0.7688, ValidA=0.7753
# Reward:0.95
# MetaL:3.6008(A:3.6072,C:0.4945,E:5.0739)
#
# ===== Iteration 33/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.7821, ValidA=0.7748
# TargEdit:Typ=3,Stg=2 Src=5->Dest=8 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 91,951
#   PostE1: TrainL=1.6092, TrainA=0.3475
#   PostE2: TrainL=1.5994, TrainA=0.3554
#   PostE3: TrainL=1.5677, TrainA=0.3644
#   PostE4: TrainL=1.5849, TrainA=0.3940
#   PostE5: TrainL=1.5915, TrainA=0.3575
#   PostE6: TrainL=1.5650, TrainA=0.3943
#   PostE7: TrainL=1.5294, TrainA=0.3907
#   PostE8: TrainL=1.5388, TrainA=0.3828
#   PostE9: TrainL=1.5143, TrainA=0.3266
#   PostE10: TrainL=1.5755, TrainA=0.3800
# PostVal: ValidL=0.7491, ValidA=0.7854
# Reward:1.06
# MetaL:6.5757(A:6.6428,C:0.6357,E:7.6986)
#
# ===== Iteration 34/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.7705, ValidA=0.7845
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 91,951
#   PostE1: TrainL=1.6113, TrainA=0.3708
#   PostE2: TrainL=1.5677, TrainA=0.3536
#   PostE3: TrainL=1.5295, TrainA=0.3969
#   PostE4: TrainL=1.5805, TrainA=0.3739
#   PostE5: TrainL=1.5781, TrainA=0.3893
#   PostE6: TrainL=1.5346, TrainA=0.3565
#   PostE7: TrainL=1.5470, TrainA=0.3927
#   PostE8: TrainL=1.5244, TrainA=0.3894
#   PostE9: TrainL=1.5453, TrainA=0.3787
#   PostE10: TrainL=1.5401, TrainA=0.3789
# PostVal: ValidL=0.7717, ValidA=0.7867
# Reward:0.22
# MetaL:-0.3511(A:-0.1657,C:0.0028,E:3.7367)
#
# ===== Iteration 35/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=64, Params: 7,449
# PreVal: ValidL=0.7427, ValidA=0.7898
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 91,951
#   Widening MetaAgentGNN: GNN Hidden Dim 64 -> 128
# MetaAgentGNN arch changed. New Params: 22093. Re-init optimizer.
#   PostE1: TrainL=1.6522, TrainA=0.3663
#   PostE2: TrainL=1.6110, TrainA=0.4087
#   PostE3: TrainL=1.5769, TrainA=0.4039
#   PostE4: TrainL=1.5333, TrainA=0.3976
#   PostE5: TrainL=1.5633, TrainA=0.3595
#   PostE6: TrainL=1.5818, TrainA=0.3831
#   PostE7: TrainL=1.5438, TrainA=0.3912
#   PostE8: TrainL=1.5474, TrainA=0.3690
#   PostE9: TrainL=1.5307, TrainA=0.4163
#   PostE10: TrainL=1.5239, TrainA=0.3784
# PostVal: ValidL=0.7258, ValidA=0.7894
# Reward:0.96
# MetaL:2.4707(A:2.4341,C:0.4471,E:3.7387)
#
# ===== Iteration 36/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,093
# PreVal: ValidL=0.7345, ValidA=0.7900
# TargEdit:Typ=3,Stg=1 Src=2->Dest=10 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 95,119
#   PostE1: TrainL=1.6321, TrainA=0.3397
#   PostE2: TrainL=1.5731, TrainA=0.3885
#   PostE3: TrainL=1.5790, TrainA=0.3522
#   PostE4: TrainL=1.5407, TrainA=0.4080
#   PostE5: TrainL=1.5236, TrainA=0.3794
#   PostE6: TrainL=1.5591, TrainA=0.3465
#   PostE7: TrainL=1.4973, TrainA=0.3825
#   PostE8: TrainL=1.5367, TrainA=0.3556
#   PostE9: TrainL=1.5091, TrainA=0.3436
#   PostE10: TrainL=1.5136, TrainA=0.4049
# PostVal: ValidL=0.7250, ValidA=0.7932
# Reward:0.32
# MetaL:7.0770(A:6.9928,C:0.9313,E:7.6288)
#
# ===== Iteration 37/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,093
# PreVal: ValidL=0.7266, ValidA=0.7950
# TargEdit:Typ=2,Stg=1 Op=3,RszF=0.25 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 82,959
#   PostE1: TrainL=1.7836, TrainA=0.2936
#   PostE2: TrainL=1.6702, TrainA=0.3492
#   PostE3: TrainL=1.6535, TrainA=0.3434
#   PostE4: TrainL=1.6093, TrainA=0.3662
#   PostE5: TrainL=1.5747, TrainA=0.3377
#   PostE6: TrainL=1.5908, TrainA=0.3492
#   PostE7: TrainL=1.5965, TrainA=0.3440
#   PostE8: TrainL=1.6186, TrainA=0.3882
#   PostE9: TrainL=1.5774, TrainA=0.3494
#   PostE10: TrainL=1.5899, TrainA=0.4091
# PostVal: ValidL=0.8344, ValidA=0.7665
# Reward:-2.85
# MetaL:-15.9645(A:-18.1586,C:5.1287,E:7.4039)
#
# ===== Iteration 38/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,093
# PreVal: ValidL=0.7878, ValidA=0.7717
# TargEdit:Typ=3,Stg=0 Src=3->Dest=5 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 82,959
#   PostE1: TrainL=1.6838, TrainA=0.3471
#   PostE2: TrainL=1.6610, TrainA=0.3744
#   PostE3: TrainL=1.5742, TrainA=0.3740
#   PostE4: TrainL=1.5877, TrainA=0.3741
#   PostE5: TrainL=1.5844, TrainA=0.3837
#   PostE6: TrainL=1.6133, TrainA=0.3543
#   PostE7: TrainL=1.5003, TrainA=0.3793
#   PostE8: TrainL=1.5930, TrainA=0.3787
#   PostE9: TrainL=1.5316, TrainA=0.3589
#   PostE10: TrainL=1.5503, TrainA=0.4159
# PostVal: ValidL=0.7316, ValidA=0.7850
# Reward:1.33
# MetaL:13.2840(A:11.7604,C:3.6625,E:6.1537)
#
# ===== Iteration 39/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,093
# PreVal: ValidL=0.7677, ValidA=0.7835
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 82,959
#   PostE1: TrainL=1.6546, TrainA=0.3503
#   PostE2: TrainL=1.5933, TrainA=0.3537
#   PostE3: TrainL=1.5649, TrainA=0.3758
#   PostE4: TrainL=1.5843, TrainA=0.4003
#   PostE5: TrainL=1.5694, TrainA=0.3713
#   PostE6: TrainL=1.5687, TrainA=0.3871
#   PostE7: TrainL=1.5929, TrainA=0.3952
#   PostE8: TrainL=1.5022, TrainA=0.4050
#   PostE9: TrainL=1.5214, TrainA=0.3847
#   PostE10: TrainL=1.5527, TrainA=0.3817
# PostVal: ValidL=0.7488, ValidA=0.7835
# Reward:0.00
# MetaL:2.4777(A:2.5090,C:0.3130,E:3.7557)
#
# ===== Iteration 40/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,093
# PreVal: ValidL=0.7582, ValidA=0.7847
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 82,959
#   Deepened MLP head 'head_target_conv_ch_mult' (Linear -> Sequential)
# MetaAgentGNN arch changed. New Params: 22105. Re-init optimizer.
#   PostE1: TrainL=1.6267, TrainA=0.3194
#   PostE2: TrainL=1.5464, TrainA=0.4040
#   PostE3: TrainL=1.5670, TrainA=0.3786
#   PostE4: TrainL=1.5556, TrainA=0.3323
#   PostE5: TrainL=1.5280, TrainA=0.4184
#   PostE6: TrainL=1.5255, TrainA=0.3623
#   PostE7: TrainL=1.5318, TrainA=0.4043
#   PostE8: TrainL=1.5414, TrainA=0.3806
#   PostE9: TrainL=1.5129, TrainA=0.3840
#   PostE10: TrainL=1.5358, TrainA=0.3780
# PostVal: ValidL=0.7609, ValidA=0.7903
# Reward:1.56
# MetaL:10.0268(A:8.0595,C:4.3095,E:3.7505)
#
# ===== Iteration 41/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,105
# PreVal: ValidL=0.7308, ValidA=0.7934
# TargEdit:Typ=0,Stg=1 K=1,CHM=1.0 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 85,263
#   PostE1: TrainL=1.9960, TrainA=0.2077
#   PostE2: TrainL=1.7621, TrainA=0.3193
#   PostE3: TrainL=1.7625, TrainA=0.3064
#   PostE4: TrainL=1.6847, TrainA=0.3352
#   PostE5: TrainL=1.6175, TrainA=0.3660
#   PostE6: TrainL=1.6712, TrainA=0.3519
#   PostE7: TrainL=1.6388, TrainA=0.3334
#   PostE8: TrainL=1.6370, TrainA=0.3450
#   PostE9: TrainL=1.6117, TrainA=0.3627
#   PostE10: TrainL=1.6294, TrainA=0.3612
# PostVal: ValidL=0.8874, ValidA=0.7392
# Reward:-5.42
# MetaL:-18.5481(A:-30.6317,C:24.7205,E:5.5329)
#
# ===== Iteration 42/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,105
# PreVal: ValidL=0.8405, ValidA=0.7435
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 85,263
#   PostE1: TrainL=1.7210, TrainA=0.3334
#   PostE2: TrainL=1.6500, TrainA=0.3611
#   PostE3: TrainL=1.6148, TrainA=0.3378
#   PostE4: TrainL=1.6537, TrainA=0.3384
#   PostE5: TrainL=1.6593, TrainA=0.3583
#   PostE6: TrainL=1.6456, TrainA=0.3412
#   PostE7: TrainL=1.6445, TrainA=0.3303
#   PostE8: TrainL=1.5961, TrainA=0.4175
#   PostE9: TrainL=1.5835, TrainA=0.3823
#   PostE10: TrainL=1.5525, TrainA=0.3758
# PostVal: ValidL=0.8139, ValidA=0.7593
# Reward:1.58
# MetaL:9.5160(A:7.6341,C:4.1378,E:3.7388)
#
# ===== Iteration 43/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,105
# PreVal: ValidL=0.8484, ValidA=0.7569
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 85,263
#   PostE1: TrainL=1.6820, TrainA=0.3146
#   PostE2: TrainL=1.6540, TrainA=0.3654
#   PostE3: TrainL=1.6496, TrainA=0.3859
#   PostE4: TrainL=1.6009, TrainA=0.3724
#   PostE5: TrainL=1.6225, TrainA=0.3364
#   PostE6: TrainL=1.5654, TrainA=0.3736
#   PostE7: TrainL=1.5632, TrainA=0.3615
#   PostE8: TrainL=1.5313, TrainA=0.3542
#   PostE9: TrainL=1.5245, TrainA=0.3789
#   PostE10: TrainL=1.5208, TrainA=0.4023
# PostVal: ValidL=0.8064, ValidA=0.7733
# Reward:1.64
# MetaL:8.1588(A:6.1977,C:4.2957,E:3.7360)
#
# ===== Iteration 44/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,105
# PreVal: ValidL=0.7671, ValidA=0.7728
# TargEdit:Typ=2,Stg=1 Op=3,RszF=0.5 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 83,135
#   PostE1: TrainL=1.8568, TrainA=0.2926
#   PostE2: TrainL=1.7284, TrainA=0.3185
#   PostE3: TrainL=1.6707, TrainA=0.3411
#   PostE4: TrainL=1.6738, TrainA=0.3806
#   PostE5: TrainL=1.6276, TrainA=0.3426
#   PostE6: TrainL=1.6514, TrainA=0.3217
#   PostE7: TrainL=1.6415, TrainA=0.3446
#   PostE8: TrainL=1.5989, TrainA=0.3688
#   PostE9: TrainL=1.6161, TrainA=0.3914
#   PostE10: TrainL=1.5689, TrainA=0.3378
# PostVal: ValidL=0.8522, ValidA=0.7463
# Reward:-2.65
# MetaL:-14.7077(A:-16.9074,C:5.1525,E:7.5308)
#
# ===== Iteration 45/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,105
# PreVal: ValidL=0.8363, ValidA=0.7484
# TargEdit:Typ=0,Stg=0 K=3,CHM=2.0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 95,825
#   Deepened MLP head 'head_target_resize_factor' (Linear -> Sequential)
# MetaAgentGNN arch changed. New Params: 22177. Re-init optimizer.
#   PostE1: TrainL=2.2356, TrainA=0.1680
#   PostE2: TrainL=2.0240, TrainA=0.2267
#   PostE3: TrainL=1.9541, TrainA=0.2378
#   PostE4: TrainL=1.8885, TrainA=0.2835
#   PostE5: TrainL=1.8649, TrainA=0.2640
#   PostE6: TrainL=1.8148, TrainA=0.3124
#   PostE7: TrainL=1.7964, TrainA=0.2984
#   PostE8: TrainL=1.7788, TrainA=0.3174
#   PostE9: TrainL=1.7443, TrainA=0.3378
#   PostE10: TrainL=1.7573, TrainA=0.3198
# PostVal: ValidL=1.0678, ValidA=0.6535
#   !!! ACCURACY DROP > 8% (0.7484 -> 0.6535). REVERTING MODEL. !!!
# Reward:-10.00
# MetaL:-10.2500(A:-56.3526,C:92.7546,E:5.4931)
#
# ===== Iteration 46/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,177
# PreVal: ValidL=0.8795, ValidA=0.7436
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 83,135
#   PostE1: TrainL=1.7520, TrainA=0.3452
#   PostE2: TrainL=1.6292, TrainA=0.3243
#   PostE3: TrainL=1.6256, TrainA=0.3574
#   PostE4: TrainL=1.6586, TrainA=0.3482
#   PostE5: TrainL=1.6061, TrainA=0.3858
#   PostE6: TrainL=1.6379, TrainA=0.3582
#   PostE7: TrainL=1.6101, TrainA=0.3919
#   PostE8: TrainL=1.6244, TrainA=0.3560
#   PostE9: TrainL=1.5749, TrainA=0.3852
#   PostE10: TrainL=1.5420, TrainA=0.3230
# PostVal: ValidL=0.8050, ValidA=0.7632
# Reward:1.96
# MetaL:9.8723(A:7.1838,C:5.7473,E:3.7024)
#
# ===== Iteration 47/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,177
# PreVal: ValidL=0.8229, ValidA=0.7610
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 83,135
#   PostE1: TrainL=1.7248, TrainA=0.3628
#   PostE2: TrainL=1.6450, TrainA=0.3421
#   PostE3: TrainL=1.6409, TrainA=0.3813
#   PostE4: TrainL=1.5962, TrainA=0.3327
#   PostE5: TrainL=1.5658, TrainA=0.4015
#   PostE6: TrainL=1.5718, TrainA=0.3804
#   PostE7: TrainL=1.5881, TrainA=0.3705
#   PostE8: TrainL=1.5690, TrainA=0.3786
#   PostE9: TrainL=1.5685, TrainA=0.3761
#   PostE10: TrainL=1.5973, TrainA=0.3720
# PostVal: ValidL=0.8150, ValidA=0.7681
# Reward:0.71
# MetaL:4.5441(A:4.0876,C:1.2812,E:3.6814)
#
# ===== Iteration 48/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,177
# PreVal: ValidL=0.7784, ValidA=0.7723
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 83,135
#   PostE1: TrainL=1.6181, TrainA=0.3377
#   PostE2: TrainL=1.6004, TrainA=0.3298
#   PostE3: TrainL=1.6162, TrainA=0.3676
#   PostE4: TrainL=1.6106, TrainA=0.3832
#   PostE5: TrainL=1.5996, TrainA=0.4037
#   PostE6: TrainL=1.5459, TrainA=0.3811
#   PostE7: TrainL=1.5801, TrainA=0.3823
#   PostE8: TrainL=1.5722, TrainA=0.3936
#   PostE9: TrainL=1.5544, TrainA=0.4054
#   PostE10: TrainL=1.5049, TrainA=0.3897
# PostVal: ValidL=0.7710, ValidA=0.7752
# Reward:0.29
# MetaL:2.3571(A:2.3089,C:0.4634,E:3.6711)
#
# ===== Iteration 49/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,177
# PreVal: ValidL=0.7613, ValidA=0.7777
# TargEdit:Typ=2,Stg=0 Op=0,RszF=1.25 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 85,547
#   PostE1: TrainL=1.6031, TrainA=0.3425
#   PostE2: TrainL=1.5785, TrainA=0.3714
#   PostE3: TrainL=1.6128, TrainA=0.4022
#   PostE4: TrainL=1.5756, TrainA=0.3513
#   PostE5: TrainL=1.5453, TrainA=0.3757
#   PostE6: TrainL=1.5656, TrainA=0.3634
#   PostE7: TrainL=1.6008, TrainA=0.4226
#   PostE8: TrainL=1.5863, TrainA=0.4535
#   PostE9: TrainL=1.5187, TrainA=0.3662
#   PostE10: TrainL=1.5346, TrainA=0.3768
# PostVal: ValidL=0.7545, ValidA=0.7844
# Reward:0.67
# MetaL:5.3874(A:5.1454,C:1.0523,E:5.6828)
#
# ===== Iteration 50/200 =====
# Current MetaAgentGNN: GNN Layers=2, GNN Hidden=128, Params: 22,177
# PreVal: ValidL=0.7731, ValidA=0.7828
# TargEdit:Typ=2,Stg=1 Op=14,RszF=4.0 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 175,403
#   Deepening MetaAgentGNN: GNN Layers 2 -> 3
# MetaAgentGNN arch changed. New Params: 38689. Re-init optimizer.
#   PostE1: TrainL=1.6408, TrainA=0.3493
#   PostE2: TrainL=1.5560, TrainA=0.3724
#   PostE3: TrainL=1.5752, TrainA=0.3460
#   PostE4: TrainL=1.6081, TrainA=0.3512
#   PostE5: TrainL=1.5574, TrainA=0.3589
#   PostE6: TrainL=1.5725, TrainA=0.4044
#   PostE7: TrainL=1.5512, TrainA=0.3986
#   PostE8: TrainL=1.5477, TrainA=0.3649
#   PostE9: TrainL=1.5389, TrainA=0.3587
#   PostE10: TrainL=1.5650, TrainA=0.3890
# PostVal: ValidL=0.7601, ValidA=0.7896
# Reward:1.68
# MetaL:16.1818(A:14.5646,C:3.9799,E:7.4540)
#
# ===== Iteration 51/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=128, Params: 38,689
# PreVal: ValidL=0.7990, ValidA=0.7847
# TargEdit:Typ=2,Stg=1 Op=14,RszF=1.5 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 235,307
#   PostE1: TrainL=1.5891, TrainA=0.3716
#   PostE2: TrainL=1.5829, TrainA=0.3958
#   PostE3: TrainL=1.6077, TrainA=0.3609
#   PostE4: TrainL=1.5510, TrainA=0.3631
#   PostE5: TrainL=1.5861, TrainA=0.3749
#   PostE6: TrainL=1.5571, TrainA=0.3783
#   PostE7: TrainL=1.5789, TrainA=0.3691
#   PostE8: TrainL=1.5128, TrainA=0.3891
#   PostE9: TrainL=1.5328, TrainA=0.3691
#   PostE10: TrainL=1.5502, TrainA=0.4132
# PostVal: ValidL=0.7409, ValidA=0.7923
# Reward:0.76
# MetaL:8.3123(A:8.1628,C:1.0443,E:7.4528)
#
# ===== Iteration 52/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=128, Params: 38,689
# PreVal: ValidL=0.7969, ValidA=0.7887
# TargEdit:Typ=2,Stg=0 Op=0,RszF=4.0 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 269,678
#   PostE1: TrainL=1.6813, TrainA=0.3074
#   PostE2: TrainL=1.5980, TrainA=0.3251
#   PostE3: TrainL=1.5651, TrainA=0.3815
#   PostE4: TrainL=1.5767, TrainA=0.3696
#   PostE5: TrainL=1.5585, TrainA=0.3877
#   PostE6: TrainL=1.5497, TrainA=0.4011
#   PostE7: TrainL=1.5202, TrainA=0.3490
#   PostE8: TrainL=1.5331, TrainA=0.3723
#   PostE9: TrainL=1.5027, TrainA=0.4007
#   PostE10: TrainL=1.4757, TrainA=0.3752
# PostVal: ValidL=0.7174, ValidA=0.7948
# Reward:0.61
# MetaL:3.8633(A:3.8510,C:0.5924,E:5.6794)
#
# ===== Iteration 53/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=128, Params: 38,689
# PreVal: ValidL=0.7458, ValidA=0.7936
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 269,678
#   PostE1: TrainL=1.6021, TrainA=0.4016
#   PostE2: TrainL=1.5493, TrainA=0.3520
#   PostE3: TrainL=1.5471, TrainA=0.3770
#   PostE4: TrainL=1.5708, TrainA=0.3919
#   PostE5: TrainL=1.5532, TrainA=0.3861
#   PostE6: TrainL=1.4911, TrainA=0.3749
#   PostE7: TrainL=1.5461, TrainA=0.3589
#   PostE8: TrainL=1.4804, TrainA=0.4030
#   PostE9: TrainL=1.4906, TrainA=0.3717
#   PostE10: TrainL=1.4996, TrainA=0.3641
# PostVal: ValidL=0.7442, ValidA=0.7941
# Reward:0.05
# MetaL:0.1963(A:0.3753,C:0.0094,E:3.6740)
#
# ===== Iteration 54/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=128, Params: 38,689
# PreVal: ValidL=0.7550, ValidA=0.7980
# TargEdit:Typ=0,Stg=2 K=1,CHM=1.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 273,774
#   PostE1: TrainL=1.7700, TrainA=0.3024
#   PostE2: TrainL=1.5502, TrainA=0.3561
#   PostE3: TrainL=1.5697, TrainA=0.3433
#   PostE4: TrainL=1.5512, TrainA=0.3315
#   PostE5: TrainL=1.5459, TrainA=0.3849
#   PostE6: TrainL=1.5327, TrainA=0.3689
#   PostE7: TrainL=1.5417, TrainA=0.3946
#   PostE8: TrainL=1.5244, TrainA=0.3653
#   PostE9: TrainL=1.4761, TrainA=0.3932
#   PostE10: TrainL=1.5382, TrainA=0.4070
# PostVal: ValidL=0.7134, ValidA=0.8014
# Reward:0.34
# MetaL:1.9716(A:2.2062,C:0.0750,E:5.4428)
#
# ===== Iteration 55/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=128, Params: 38,689
# PreVal: ValidL=0.7068, ValidA=0.8042
# TargEdit:Typ=1,Stg=0 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 273,774
#   Widening MetaAgentGNN: GNN Hidden Dim 128 -> 256
# MetaAgentGNN arch changed. New Params: 141773. Re-init optimizer.
#   PostE1: TrainL=1.6424, TrainA=0.3409
#   PostE2: TrainL=1.5441, TrainA=0.3736
#   PostE3: TrainL=1.5548, TrainA=0.4053
#   PostE4: TrainL=1.5343, TrainA=0.3730
#   PostE5: TrainL=1.5722, TrainA=0.3684
#   PostE6: TrainL=1.5309, TrainA=0.4017
#   PostE7: TrainL=1.5362, TrainA=0.3954
#   PostE8: TrainL=1.5228, TrainA=0.4191
#   PostE9: TrainL=1.5379, TrainA=0.4193
#   PostE10: TrainL=1.4945, TrainA=0.3871
# PostVal: ValidL=0.6820, ValidA=0.8048
# Reward:1.06
# MetaL:2.8134(A:2.6110,C:0.7738,E:3.6900)
#
# ===== Iteration 56/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,773
# PreVal: ValidL=0.6973, ValidA=0.8054
# TargEdit:Typ=0,Stg=0 K=3,CHM=2.0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 421,518
#   PostE1: TrainL=2.2862, TrainA=0.1849
#   PostE2: TrainL=2.0043, TrainA=0.2383
#   PostE3: TrainL=1.9203, TrainA=0.2652
#   PostE4: TrainL=1.8595, TrainA=0.2665
#   PostE5: TrainL=1.8668, TrainA=0.2889
#   PostE6: TrainL=1.7853, TrainA=0.2790
#   PostE7: TrainL=1.7740, TrainA=0.3233
#   PostE8: TrainL=1.7303, TrainA=0.3125
#   PostE9: TrainL=1.6996, TrainA=0.3435
#   PostE10: TrainL=1.7023, TrainA=0.3043
# PostVal: ValidL=0.9845, ValidA=0.6893
#   !!! ACCURACY DROP > 8% (0.8054 -> 0.6893). REVERTING MODEL. !!!
# Reward:-10.00
# MetaL:-3.6522(A:-48.0786,C:89.3395,E:4.8664)
#
# ===== Iteration 57/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,773
# PreVal: ValidL=0.7115, ValidA=0.8054
# TargEdit:Typ=2,Stg=2 Op=12,RszF=4.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 287,982
#   PostE1: TrainL=1.7107, TrainA=0.3179
#   PostE2: TrainL=1.5319, TrainA=0.3597
#   PostE3: TrainL=1.5574, TrainA=0.4057
#   PostE4: TrainL=1.5364, TrainA=0.3509
#   PostE5: TrainL=1.5511, TrainA=0.3778
#   PostE6: TrainL=1.5035, TrainA=0.4720
#   PostE7: TrainL=1.5396, TrainA=0.3999
#   PostE8: TrainL=1.5084, TrainA=0.4288
#   PostE9: TrainL=1.4908, TrainA=0.4303
#   PostE10: TrainL=1.5076, TrainA=0.3830
# PostVal: ValidL=0.7270, ValidA=0.8114
# Reward:0.60
# MetaL:11.4491(A:10.7000,C:2.1941,E:6.9594)
#
# ===== Iteration 58/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,773
# PreVal: ValidL=0.6810, ValidA=0.8130
# TargEdit:Typ=3,Stg=1 Src=11->Dest=15 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 302,382
#   PostE1: TrainL=1.5866, TrainA=0.3870
#   PostE2: TrainL=1.5497, TrainA=0.3945
#   PostE3: TrainL=1.5192, TrainA=0.3752
#   PostE4: TrainL=1.5057, TrainA=0.4101
#   PostE5: TrainL=1.5281, TrainA=0.4036
#   PostE6: TrainL=1.5079, TrainA=0.4386
#   PostE7: TrainL=1.5116, TrainA=0.3646
#   PostE8: TrainL=1.5169, TrainA=0.3508
#   PostE9: TrainL=1.4264, TrainA=0.4210
#   PostE10: TrainL=1.5446, TrainA=0.4103
# PostVal: ValidL=0.6815, ValidA=0.8112
# Reward:-0.18
# MetaL:5.9246(A:6.1261,C:0.4434,E:8.4634)
#
# ===== Iteration 59/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,773
# PreVal: ValidL=0.6733, ValidA=0.8138
# TargEdit:Typ=2,Stg=0 Op=0,RszF=4.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 439,866
#   PostE1: TrainL=1.5610, TrainA=0.4142
#   PostE2: TrainL=1.5317, TrainA=0.3579
#   PostE3: TrainL=1.5670, TrainA=0.4158
#   PostE4: TrainL=1.5324, TrainA=0.3641
#   PostE5: TrainL=1.5264, TrainA=0.3873
#   PostE6: TrainL=1.5004, TrainA=0.4101
#   PostE7: TrainL=1.5419, TrainA=0.3426
#   PostE8: TrainL=1.5085, TrainA=0.4409
#   PostE9: TrainL=1.4745, TrainA=0.3854
#   PostE10: TrainL=1.5155, TrainA=0.3817
# PostVal: ValidL=0.6441, ValidA=0.8178
# Reward:0.40
# MetaL:5.9006(A:5.5689,C:1.1904,E:5.2696)
#
# ===== Iteration 60/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,773
# PreVal: ValidL=0.6712, ValidA=0.8168
# TargEdit:Typ=2,Stg=1 Op=0,RszF=3.0 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 797,114
#   Deepened MLP head 'head_target_conv_kernel' (Linear -> Sequential)
# MetaAgentGNN arch changed. New Params: 141779. Re-init optimizer.
#   PostE1: TrainL=1.5857, TrainA=0.3551
#   PostE2: TrainL=1.5852, TrainA=0.4161
#   PostE3: TrainL=1.5440, TrainA=0.3816
#   PostE4: TrainL=1.5782, TrainA=0.4154
#   PostE5: TrainL=1.4710, TrainA=0.3890
#   PostE6: TrainL=1.5423, TrainA=0.3907
#   PostE7: TrainL=1.4586, TrainA=0.4123
#   PostE8: TrainL=1.5032, TrainA=0.4066
#   PostE9: TrainL=1.4316, TrainA=0.3951
#   PostE10: TrainL=1.4816, TrainA=0.4475
# PostVal: ValidL=0.6609, ValidA=0.8205
# Reward:1.37
# MetaL:13.9115(A:12.4456,C:3.6221,E:6.9039)
#
# ===== Iteration 61/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,779
# PreVal: ValidL=0.6510, ValidA=0.8222
# TargEdit:Typ=3,Stg=0 Src=2->Dest=11 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 797,114
#   PostE1: TrainL=1.5899, TrainA=0.3797
#   PostE2: TrainL=1.5478, TrainA=0.3861
#   PostE3: TrainL=1.5849, TrainA=0.4053
#   PostE4: TrainL=1.5266, TrainA=0.3960
#   PostE5: TrainL=1.4673, TrainA=0.3951
#   PostE6: TrainL=1.4761, TrainA=0.3701
#   PostE7: TrainL=1.5003, TrainA=0.3951
#   PostE8: TrainL=1.4361, TrainA=0.4036
#   PostE9: TrainL=1.4510, TrainA=0.4082
#   PostE10: TrainL=1.4752, TrainA=0.4305
# PostVal: ValidL=0.6661, ValidA=0.8212
# Reward:-0.10
# MetaL:0.2185(A:0.5703,C:0.0034,E:7.0697)
#
# ===== Iteration 62/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,779
# PreVal: ValidL=0.6752, ValidA=0.8224
# TargEdit:Typ=2,Stg=0 Op=0,RszF=3.0 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 1,864,154
#   PostE1: TrainL=1.6421, TrainA=0.3702
#   PostE2: TrainL=1.5464, TrainA=0.3687
#   PostE3: TrainL=1.5521, TrainA=0.3840
#   PostE4: TrainL=1.5013, TrainA=0.3815
#   PostE5: TrainL=1.5179, TrainA=0.4036
#   PostE6: TrainL=1.5110, TrainA=0.4268
#   PostE7: TrainL=1.4887, TrainA=0.4368
#   PostE8: TrainL=1.4790, TrainA=0.4699
#   PostE9: TrainL=1.4775, TrainA=0.4164
#   PostE10: TrainL=1.4659, TrainA=0.4012
# PostVal: ValidL=0.6649, ValidA=0.8221
# Reward:-0.03
# MetaL:-1.2444(A:-1.0276,C:0.0561,E:4.8973)
#
# ===== Iteration 63/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,779
# PreVal: ValidL=0.6555, ValidA=0.8258
# TargEdit:Typ=3,Stg=1 Src=7->Dest=10 | MetaSelfEdit:Typ=1
#   TargetCNN arch changed. New Params: 1,865,402
#   PostE1: TrainL=1.5787, TrainA=0.3912
#   PostE2: TrainL=1.5096, TrainA=0.3596
#   PostE3: TrainL=1.5196, TrainA=0.3811
#   PostE4: TrainL=1.5603, TrainA=0.3989
#   PostE5: TrainL=1.5200, TrainA=0.3877
#   PostE6: TrainL=1.5089, TrainA=0.3599
#   PostE7: TrainL=1.4839, TrainA=0.4154
#   PostE8: TrainL=1.5029, TrainA=0.3918
#   PostE9: TrainL=1.4452, TrainA=0.3874
#   PostE10: TrainL=1.4232, TrainA=0.4355
# PostVal: ValidL=0.6691, ValidA=0.8261
# Reward:0.03
# MetaL:-1.9913(A:-1.5892,C:0.0267,E:8.3092)
#
# ===== Iteration 64/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,779
# PreVal: ValidL=0.6534, ValidA=0.8265
# TargEdit:Typ=1,Stg=1 | MetaSelfEdit:Typ=0
#   TargetCNN arch changed. New Params: 1,865,402
#   PostE1: TrainL=1.5871, TrainA=0.3889
#   PostE2: TrainL=1.4979, TrainA=0.4038
#   PostE3: TrainL=1.5391, TrainA=0.3916
#   PostE4: TrainL=1.5157, TrainA=0.3896
#   PostE5: TrainL=1.5056, TrainA=0.4248
#   PostE6: TrainL=1.4741, TrainA=0.4258
#   PostE7: TrainL=1.4781, TrainA=0.3830
#   PostE8: TrainL=1.4392, TrainA=0.3897
#   PostE9: TrainL=1.4568, TrainA=0.3924
#   PostE10: TrainL=1.4218, TrainA=0.3715
# PostVal: ValidL=0.6106, ValidA=0.8356
# Reward:0.91
# MetaL:2.6680(A:2.5200,C:0.6257,E:3.2971)
#
# ===== Iteration 65/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=256, Params: 141,779
# PreVal: ValidL=0.6643, ValidA=0.8333
# TargEdit:Typ=0,Stg=1 K=3,CHM=0.5 | MetaSelfEdit:Typ=2
#   TargetCNN arch changed. New Params: 2,155,706
#   Widening MetaAgentGNN: GNN Hidden Dim 256 -> 512
# MetaAgentGNN arch changed. New Params: 544717. Re-init optimizer.
#   PostE1: TrainL=1.9471, TrainA=0.2623
#   PostE2: TrainL=1.7246, TrainA=0.3213
#   PostE3: TrainL=1.6337, TrainA=0.3807
#   PostE4: TrainL=1.6007, TrainA=0.3444
#   PostE5: TrainL=1.5621, TrainA=0.3256
#   PostE6: TrainL=1.5413, TrainA=0.3561
#   PostE7: TrainL=1.5272, TrainA=0.4123
#   PostE8: TrainL=1.5569, TrainA=0.3650
#   PostE9: TrainL=1.5559, TrainA=0.4251
#   PostE10: TrainL=1.4828, TrainA=0.3818
# PostVal: ValidL=0.6927, ValidA=0.8052
# Reward:-1.81
# ...
# PostVal: ValidL=0.4667, ValidA=0.9020
# Reward:-0.29
# MetaL:0.8464(A:1.0940,C:0.0398,E:5.3487)
#
# ===== Iteration 180/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,089
# PreVal: ValidL=0.4278, ValidA=0.9047
# TargEdit:Typ=3,Stg=1 Src=4->Dest=110 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,532,690
#   Deepened Seq head 'head_target_conv_ch_mult'.
# MetaAgentGNN arch changed. New Params: 545101. Re-init optimizer.
#   PostE1: TrainL=1.2879, TrainA=0.4725
#   PostE2: TrainL=1.2239, TrainA=0.4245
#   PostE3: TrainL=1.2395, TrainA=0.4650
#   PostE4: TrainL=1.3062, TrainA=0.4500
#   PostE5: TrainL=1.2837, TrainA=0.3881
#   PostE6: TrainL=1.1631, TrainA=0.4778
#   PostE7: TrainL=1.2806, TrainA=0.4959
#   PostE8: TrainL=1.2016, TrainA=0.4962
#   PostE9: TrainL=1.2148, TrainA=0.4863
#   PostE10: TrainL=1.2489, TrainA=0.4778
# PostVal: ValidL=0.4937, ValidA=0.8999
# Reward:0.52
# MetaL:2.2722(A:2.4280,C:0.2350,E:5.4674)
#
# ===== Iteration 181/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,101
# PreVal: ValidL=0.4652, ValidA=0.9009
# TargEdit:Typ=3,Stg=1 Src=16->Dest=100 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,547,090
#   PostE1: TrainL=1.3341, TrainA=0.4804
#   PostE2: TrainL=1.2799, TrainA=0.4440
#   PostE3: TrainL=1.2635, TrainA=0.4625
#   PostE4: TrainL=1.2637, TrainA=0.4404
#   PostE5: TrainL=1.2601, TrainA=0.4556
#   PostE6: TrainL=1.1746, TrainA=0.4480
#   PostE7: TrainL=1.2669, TrainA=0.4486
#   PostE8: TrainL=1.2956, TrainA=0.5098
#   PostE9: TrainL=1.1622, TrainA=0.4313
#   PostE10: TrainL=1.2573, TrainA=0.4647
# PostVal: ValidL=0.4629, ValidA=0.9005
# Reward:-0.04
# MetaL:-9.6422(A:-11.6078,C:4.4738,E:5.4262)
#
# ===== Iteration 182/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,101
# PreVal: ValidL=0.4421, ValidA=0.9017
# TargEdit:Typ=3,Stg=1 Src=32->Dest=111 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,547,090
#   PostE1: TrainL=1.2537, TrainA=0.5363
#   PostE2: TrainL=1.3096, TrainA=0.4514
#   PostE3: TrainL=1.2639, TrainA=0.5003
#   PostE4: TrainL=1.2477, TrainA=0.4624
#   PostE5: TrainL=1.2375, TrainA=0.5171
#   PostE6: TrainL=1.2243, TrainA=0.4673
#   PostE7: TrainL=1.2628, TrainA=0.4710
#   PostE8: TrainL=1.2025, TrainA=0.4616
#   PostE9: TrainL=1.2410, TrainA=0.4938
#   PostE10: TrainL=1.1915, TrainA=0.4285
# PostVal: ValidL=0.4208, ValidA=0.9012
# Reward:-0.05
# MetaL:-6.4422(A:-8.1917,C:4.0432,E:5.4435)
#
# ===== Iteration 183/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,101
# PreVal: ValidL=0.4578, ValidA=0.9010
# TargEdit:Typ=3,Stg=1 Src=5->Dest=124 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,554,578
#   PostE1: TrainL=1.2622, TrainA=0.5321
#   PostE2: TrainL=1.2327, TrainA=0.4439
#   PostE3: TrainL=1.2883, TrainA=0.5178
#   PostE4: TrainL=1.2516, TrainA=0.5344
#   PostE5: TrainL=1.2187, TrainA=0.4618
#   PostE6: TrainL=1.1733, TrainA=0.4677
#   PostE7: TrainL=1.2104, TrainA=0.4987
#   PostE8: TrainL=1.2485, TrainA=0.4313
#   PostE9: TrainL=1.2384, TrainA=0.4586
#   PostE10: TrainL=1.2341, TrainA=0.4713
# PostVal: ValidL=0.4060, ValidA=0.9027
# Reward:0.17
# MetaL:-8.0453(A:-8.2380,C:0.9384,E:5.5309)
#
# ===== Iteration 184/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,101
# PreVal: ValidL=0.4255, ValidA=0.9035
# TargEdit:Typ=3,Stg=1 Src=32->Dest=62 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,554,578
#   PostE1: TrainL=1.3168, TrainA=0.4901
#   PostE2: TrainL=1.2319, TrainA=0.5539
#   PostE3: TrainL=1.2850, TrainA=0.4195
#   PostE4: TrainL=1.2964, TrainA=0.5336
#   PostE5: TrainL=1.3370, TrainA=0.4906
#   PostE6: TrainL=1.2904, TrainA=0.4870
#   PostE7: TrainL=1.2498, TrainA=0.4827
#   PostE8: TrainL=1.2452, TrainA=0.4557
#   PostE9: TrainL=1.2353, TrainA=0.4523
#   PostE10: TrainL=1.1608, TrainA=0.4927
# PostVal: ValidL=0.4178, ValidA=0.9023
# Reward:-0.12
# MetaL:-0.8244(A:-0.5551,C:0.0148,E:5.5341)
#
# ===== Iteration 185/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,101
# PreVal: ValidL=0.4174, ValidA=0.9021
# TargEdit:Typ=3,Stg=1 Src=18->Dest=55 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,568,978
#   Deepened Seq head 'head_target_loc_stage'.
# MetaAgentGNN arch changed. New Params: 545113. Re-init optimizer.
#   PostE1: TrainL=1.2763, TrainA=0.5335
#   PostE2: TrainL=1.3094, TrainA=0.5066
#   PostE3: TrainL=1.2715, TrainA=0.4470
#   PostE4: TrainL=1.3273, TrainA=0.5537
#   PostE5: TrainL=1.2918, TrainA=0.4762
#   PostE6: TrainL=1.2212, TrainA=0.4945
#   PostE7: TrainL=1.2730, TrainA=0.4704
#   PostE8: TrainL=1.2412, TrainA=0.5022
#   PostE9: TrainL=1.1682, TrainA=0.4884
#   PostE10: TrainL=1.2478, TrainA=0.4296
# PostVal: ValidL=0.5157, ValidA=0.9007
# Reward:0.86
# MetaL:11.8650(A:9.7204,C:4.8491,E:5.5981)
#
# ===== Iteration 186/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,113
# PreVal: ValidL=0.4492, ValidA=0.9027
# TargEdit:Typ=3,Stg=1 Src=18->Dest=128 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,583,378
#   PostE1: TrainL=1.3112, TrainA=0.4274
#   PostE2: TrainL=1.2901, TrainA=0.4783
#   PostE3: TrainL=1.3498, TrainA=0.4304
#   PostE4: TrainL=1.2680, TrainA=0.5285
#   PostE5: TrainL=1.1875, TrainA=0.4865
#   PostE6: TrainL=1.2374, TrainA=0.5125
#   PostE7: TrainL=1.2722, TrainA=0.4795
#   PostE8: TrainL=1.1629, TrainA=0.5600
#   PostE9: TrainL=1.2684, TrainA=0.5185
#   PostE10: TrainL=1.2252, TrainA=0.4531
# PostVal: ValidL=0.4715, ValidA=0.9006
# Reward:-0.21
# MetaL:-3.6812(A:-3.7824,C:0.7527,E:5.5036)
#
# ===== Iteration 187/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,113
# PreVal: ValidL=0.4219, ValidA=0.9038
# TargEdit:Typ=3,Stg=1 Src=29->Dest=63 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,583,378
#   PostE1: TrainL=1.3505, TrainA=0.4691
#   PostE2: TrainL=1.1958, TrainA=0.3975
#   PostE3: TrainL=1.2287, TrainA=0.4863
#   PostE4: TrainL=1.2792, TrainA=0.4264
#   PostE5: TrainL=1.2631, TrainA=0.4988
#   PostE6: TrainL=1.2633, TrainA=0.4835
#   PostE7: TrainL=1.2309, TrainA=0.4464
#   PostE8: TrainL=1.2630, TrainA=0.4635
#   PostE9: TrainL=1.1961, TrainA=0.4490
#   PostE10: TrainL=1.2350, TrainA=0.4497
# PostVal: ValidL=0.4778, ValidA=0.9003
# Reward:-0.35
# MetaL:-4.8610(A:-4.9898,C:0.8132,E:5.5571)
#
# ===== Iteration 188/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,113
# PreVal: ValidL=0.4837, ValidA=0.9009
# TargEdit:Typ=3,Stg=1 Src=19->Dest=90 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,597,778
#   PostE1: TrainL=1.2934, TrainA=0.4908
#   PostE2: TrainL=1.2196, TrainA=0.4914
#   PostE3: TrainL=1.3034, TrainA=0.5171
#   PostE4: TrainL=1.2544, TrainA=0.5012
#   PostE5: TrainL=1.2282, TrainA=0.4739
#   PostE6: TrainL=1.2682, TrainA=0.5392
#   PostE7: TrainL=1.2664, TrainA=0.4735
#   PostE8: TrainL=1.2280, TrainA=0.4742
#   PostE9: TrainL=1.2272, TrainA=0.4918
#   PostE10: TrainL=1.2028, TrainA=0.5431
# PostVal: ValidL=0.4374, ValidA=0.9000
# Reward:-0.09
# MetaL:0.8471(A:1.1167,C:0.0235,E:5.6272)
#
# ===== Iteration 189/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,113
# PreVal: ValidL=0.4252, ValidA=0.9024
# TargEdit:Typ=3,Stg=2 Src=2->Dest=10 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,599,890
#   PostE1: TrainL=1.3121, TrainA=0.4810
#   PostE2: TrainL=1.2584, TrainA=0.4764
#   PostE3: TrainL=1.2675, TrainA=0.4380
#   PostE4: TrainL=1.2567, TrainA=0.4554
#   PostE5: TrainL=1.2487, TrainA=0.4660
#   PostE6: TrainL=1.2971, TrainA=0.4343
#   PostE7: TrainL=1.2388, TrainA=0.4906
#   PostE8: TrainL=1.2371, TrainA=0.4390
#   PostE9: TrainL=1.1855, TrainA=0.5026
#   PostE10: TrainL=1.2432, TrainA=0.4369
# PostVal: ValidL=0.4582, ValidA=0.9005
# Reward:-0.19
# MetaL:0.2025(A:0.3102,C:0.0017,E:2.1709)
#
# ===== Iteration 190/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,113
# PreVal: ValidL=0.4507, ValidA=0.9004
# TargEdit:Typ=3,Stg=1 Src=5->Dest=55 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,607,378
#   Deepened Seq head 'head_target_conv_ch_mult'.
# MetaAgentGNN arch changed. New Params: 545125. Re-init optimizer.
#   PostE1: TrainL=1.3204, TrainA=0.4316
#   PostE2: TrainL=1.2709, TrainA=0.4797
#   PostE3: TrainL=1.2660, TrainA=0.4179
#   PostE4: TrainL=1.2738, TrainA=0.4230
#   PostE5: TrainL=1.2342, TrainA=0.4800
#   PostE6: TrainL=1.2365, TrainA=0.4587
#   PostE7: TrainL=1.1440, TrainA=0.5083
#   PostE8: TrainL=1.2656, TrainA=0.4389
#   PostE9: TrainL=1.2386, TrainA=0.5030
#   PostE10: TrainL=1.2636, TrainA=0.5036
# PostVal: ValidL=0.4878, ValidA=0.9000
# Reward:0.96
# MetaL:5.4401(A:5.3489,C:0.7970,E:6.1465)
#
# ===== Iteration 191/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,125
# PreVal: ValidL=0.4666, ValidA=0.9000
# TargEdit:Typ=3,Stg=1 Src=5->Dest=83 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,614,866
#   PostE1: TrainL=1.3013, TrainA=0.4462
#   PostE2: TrainL=1.2535, TrainA=0.4628
#   PostE3: TrainL=1.2234, TrainA=0.4873
#   PostE4: TrainL=1.2105, TrainA=0.4485
#   PostE5: TrainL=1.2638, TrainA=0.4807
#   PostE6: TrainL=1.2378, TrainA=0.4558
#   PostE7: TrainL=1.2744, TrainA=0.4821
#   PostE8: TrainL=1.1991, TrainA=0.4192
#   PostE9: TrainL=1.2466, TrainA=0.4234
#   PostE10: TrainL=1.2016, TrainA=0.4504
# PostVal: ValidL=0.4157, ValidA=0.9017
# Reward:0.17
# MetaL:-8.3589(A:-9.6722,C:3.2325,E:6.0608)
#
# ===== Iteration 192/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,125
# PreVal: ValidL=0.4725, ValidA=0.9007
# TargEdit:Typ=3,Stg=1 Src=2->Dest=98 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,670,738
#   PostE1: TrainL=1.3516, TrainA=0.4863
#   PostE2: TrainL=1.3105, TrainA=0.4573
#   PostE3: TrainL=1.2669, TrainA=0.4807
#   PostE4: TrainL=1.2666, TrainA=0.4604
#   PostE5: TrainL=1.2758, TrainA=0.4754
#   PostE6: TrainL=1.2432, TrainA=0.4972
#   PostE7: TrainL=1.2584, TrainA=0.4650
#   PostE8: TrainL=1.1952, TrainA=0.5634
#   PostE9: TrainL=1.2798, TrainA=0.4544
#   PostE10: TrainL=1.2291, TrainA=0.4807
# PostVal: ValidL=0.4258, ValidA=0.9013
# Reward:0.06
# MetaL:-9.8696(A:-11.1640,C:3.2083,E:6.1942)
#
# ===== Iteration 193/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,125
# PreVal: ValidL=0.4751, ValidA=0.9010
# TargEdit:Typ=3,Stg=1 Src=6->Dest=46 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,678,226
#   PostE1: TrainL=1.3169, TrainA=0.4883
#   PostE2: TrainL=1.2893, TrainA=0.4517
#   PostE3: TrainL=1.2525, TrainA=0.4428
#   PostE4: TrainL=1.2205, TrainA=0.4440
#   PostE5: TrainL=1.2122, TrainA=0.4348
#   PostE6: TrainL=1.2342, TrainA=0.4501
#   PostE7: TrainL=1.2208, TrainA=0.5098
#   PostE8: TrainL=1.1583, TrainA=0.4145
#   PostE9: TrainL=1.1752, TrainA=0.5307
#   PostE10: TrainL=1.2627, TrainA=0.4262
# PostVal: ValidL=0.4297, ValidA=0.8999
# Reward:-0.11
# MetaL:-10.2235(A:-10.6122,C:1.4116,E:6.3434)
#
# ===== Iteration 194/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,125
# PreVal: ValidL=0.4394, ValidA=0.9008
# TargEdit:Typ=3,Stg=1 Src=21->Dest=123 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,692,626
#   PostE1: TrainL=1.2705, TrainA=0.5489
#   PostE2: TrainL=1.2945, TrainA=0.5220
#   PostE3: TrainL=1.2663, TrainA=0.4236
#   PostE4: TrainL=1.2539, TrainA=0.4339
#   PostE5: TrainL=1.2823, TrainA=0.4906
#   PostE6: TrainL=1.2464, TrainA=0.4940
#   PostE7: TrainL=1.2337, TrainA=0.5046
#   PostE8: TrainL=1.2460, TrainA=0.4869
#   PostE9: TrainL=1.2353, TrainA=0.5009
#   PostE10: TrainL=1.2279, TrainA=0.4468
# PostVal: ValidL=0.4349, ValidA=0.9018
# Reward:0.10
# MetaL:0.6244(A:0.9403,C:0.0059,E:6.3782)
#
# ===== Iteration 195/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,125
# PreVal: ValidL=0.4404, ValidA=0.9023
# TargEdit:Typ=3,Stg=1 Src=32->Dest=93 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,692,626
#   Deepened Seq head 'head_target_resize_factor'.
# MetaAgentGNN arch changed. New Params: 545197. Re-init optimizer.
#   PostE1: TrainL=1.3383, TrainA=0.4809
#   PostE2: TrainL=1.3119, TrainA=0.4400
#   PostE3: TrainL=1.2683, TrainA=0.4985
#   PostE4: TrainL=1.2166, TrainA=0.4726
#   PostE5: TrainL=1.2186, TrainA=0.4982
#   PostE6: TrainL=1.2373, TrainA=0.4583
#   PostE7: TrainL=1.2134, TrainA=0.4601
#   PostE8: TrainL=1.2341, TrainA=0.4990
#   PostE9: TrainL=1.1713, TrainA=0.4618
#   PostE10: TrainL=1.1991, TrainA=0.5165
# PostVal: ValidL=0.4502, ValidA=0.9022
# Reward:0.99
# MetaL:8.6425(A:7.9969,C:1.9633,E:6.7204)
#
# ===== Iteration 196/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,197
# PreVal: ValidL=0.4694, ValidA=0.9021
# TargEdit:Typ=3,Stg=1 Src=30->Dest=91 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,692,626
#   PostE1: TrainL=1.2748, TrainA=0.4991
#   PostE2: TrainL=1.2626, TrainA=0.4527
#   PostE3: TrainL=1.2490, TrainA=0.5299
#   PostE4: TrainL=1.2746, TrainA=0.5071
#   PostE5: TrainL=1.2815, TrainA=0.4760
#   PostE6: TrainL=1.2199, TrainA=0.4342
#   PostE7: TrainL=1.2209, TrainA=0.4591
#   PostE8: TrainL=1.1739, TrainA=0.4436
#   PostE9: TrainL=1.2749, TrainA=0.4196
#   PostE10: TrainL=1.1732, TrainA=0.4992
# PostVal: ValidL=0.4354, ValidA=0.9000
# Reward:-0.21
# MetaL:-9.1916(A:-10.2415,C:2.7484,E:6.4852)
#
# ===== Iteration 197/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,197
# PreVal: ValidL=0.4277, ValidA=0.9021
# TargEdit:Typ=3,Stg=1 Src=33->Dest=101 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,692,626
#   PostE1: TrainL=1.2694, TrainA=0.4693
#   PostE2: TrainL=1.2843, TrainA=0.4459
#   PostE3: TrainL=1.2723, TrainA=0.5172
#   PostE4: TrainL=1.2346, TrainA=0.4422
#   PostE5: TrainL=1.2980, TrainA=0.5030
#   PostE6: TrainL=1.1687, TrainA=0.4318
#   PostE7: TrainL=1.2376, TrainA=0.4429
#   PostE8: TrainL=1.1808, TrainA=0.5159
#   PostE9: TrainL=1.2623, TrainA=0.4699
#   PostE10: TrainL=1.2238, TrainA=0.4752
# PostVal: ValidL=0.4173, ValidA=0.9041
# Reward:0.20
# MetaL:-6.6212(A:-6.9562,C:1.3036,E:6.3356)
#
# ===== Iteration 198/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,197
# PreVal: ValidL=0.4731, ValidA=0.9036
# TargEdit:Typ=3,Stg=1 Src=32->Dest=122 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,692,626
#   PostE1: TrainL=1.3084, TrainA=0.4279
#   PostE2: TrainL=1.3333, TrainA=0.4043
#   PostE3: TrainL=1.2748, TrainA=0.4863
#   PostE4: TrainL=1.2562, TrainA=0.4488
#   PostE5: TrainL=1.2602, TrainA=0.4827
#   PostE6: TrainL=1.2135, TrainA=0.4582
#   PostE7: TrainL=1.2791, TrainA=0.4621
#   PostE8: TrainL=1.1898, TrainA=0.4625
#   PostE9: TrainL=1.2515, TrainA=0.4765
#   PostE10: TrainL=1.2568, TrainA=0.5122
# PostVal: ValidL=0.4897, ValidA=0.8997
# Reward:-0.39
# MetaL:-4.5979(A:-4.7721,C:0.9839,E:6.3546)
#
# ===== Iteration 199/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,197
# PreVal: ValidL=0.4675, ValidA=0.9011
# TargEdit:Typ=3,Stg=1 Src=4->Dest=63 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,700,114
#   PostE1: TrainL=1.2850, TrainA=0.4346
#   PostE2: TrainL=1.2807, TrainA=0.4996
#   PostE3: TrainL=1.2217, TrainA=0.5019
#   PostE4: TrainL=1.2154, TrainA=0.4489
#   PostE5: TrainL=1.2024, TrainA=0.4565
#   PostE6: TrainL=1.2659, TrainA=0.4193
#   PostE7: TrainL=1.2658, TrainA=0.4881
#   PostE8: TrainL=1.2509, TrainA=0.4921
#   PostE9: TrainL=1.1941, TrainA=0.4828
#   PostE10: TrainL=1.2422, TrainA=0.4970
# PostVal: ValidL=0.4179, ValidA=0.9038
# Reward:0.27
# MetaL:4.9189(A:5.0049,C:0.4790,E:6.5098)
#
# ===== Iteration 200/200 =====
# Current MetaAgentGNN: GNN Layers=3, GNN Hidden=512, Params: 545,197
# PreVal: ValidL=0.4762, ValidA=0.9021
# TargEdit:Typ=3,Stg=1 Src=33->Dest=66 | MetaSelfEdit:Typ=3
#   TargetCNN arch changed. New Params: 4,700,114
#   Deepened Seq head 'head_target_loc_stage'.
# MetaAgentGNN arch changed. New Params: 545209. Re-init optimizer.
#   PostE1: TrainL=1.2938, TrainA=0.4481
#   PostE2: TrainL=1.2864, TrainA=0.4367
#   PostE3: TrainL=1.2184, TrainA=0.4802
#   PostE4: TrainL=1.2843, TrainA=0.4575
#   PostE5: TrainL=1.1910, TrainA=0.5385
#   PostE6: TrainL=1.2531, TrainA=0.4910
#   PostE7: TrainL=1.1663, TrainA=0.4707
#   PostE8: TrainL=1.1306, TrainA=0.4730
#   PostE9: TrainL=1.2463, TrainA=0.4595
#   PostE10: TrainL=1.2484, TrainA=0.4697
# PostVal: ValidL=0.4726, ValidA=0.8995
# Reward:0.74
# MetaL:9.9604(A:9.1963,C:2.2027,E:6.7444)
#
# ===== Search Finished =====
# Final TargetCNN P: 4,700,114
# Final MetaAgentGNN: L=3,H=512,P=545,209
